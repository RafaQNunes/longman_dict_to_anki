# %% [markdown]
# # Packages
# ### Verify if all packages are OK

# %%
# Function to check and load libraries
def import_and_check(library: str, sublibrary: str = '', librename: str = '', import_module: bool = False):

    # Organizing parameters
    if librename != '': _librename = ' as ' + librename.strip()
    else: _librename = ''
    
    if sublibrary == '': text_execution = f'import {library}{_librename}'
    else: text_execution = f'from {library} import {sublibrary}{_librename}'

    if librename != '': final = librename.strip()
    elif sublibrary != '': final = sublibrary.strip()
    else: final = library.strip()
    
    # Execute check
    try:
        exec(text_execution) # Import the module just inside the function
        if import_module:
            exec(f'globals()[final] = {final}') # Move parameter to use if import_module == True
            print(f"Library {library} is installed and imported.")
        else:
            print(f"Library {library} is installed, but it is not imported.")
        return True
    except ImportError:
        print(f"Library {library} not is installed.")
        return False

# %%
# Check if a package is imported
def is_package_imported(package_name):
    return package_name in sys.modules

# %%
if 'openai' in globals(): del openai # delete openai package if it's loaded

# Load and check libraries
if import_and_check('sys', import_module = True) and \
    import_and_check('os', import_module = True) and \
    import_and_check('time', import_module = True) and \
    import_and_check('requests', import_module = True) and \
    import_and_check('bs4','BeautifulSoup', import_module = True) and \
    import_and_check('json', import_module = True) \
        : print('All necessary packages were imported')
else:
    print('Not all packages were imported. Finish the application.')
    time.sleep(5)
    exit()
# Out:
# Library sys is installed and imported.
# Library os is installed and imported.
# Library time is installed and imported.
# Library requests is installed and imported.
# Library bs4 is installed and imported.
# Library json is installed and imported.
# All necessary packages were imported

# %%
print('\nStart the application for getting meanings from ldoceonline.com with Python. By Rafael de Queiroz Nunes.')
# Out:
# Start the application for getting meanings from ldoceonline.com with Python. By Rafael de Queiroz Nunes.

# %% [markdown]
# # Variables

# %%
########################################
### Model variables

# Open the JSON file
if 'data_json' in globals(): del data_json # delete openai package if it's loaded
try:
    with open('ldoceonline_params.json', 'r') as file_json:
        data_json = json.load(file_json)
except FileNotFoundError:
    print('\nThe file ldoceonline_params.json is not found in the same path as application. Application will be closed.')
    time.sleep(5)
    exit()

# %%
# Access the data
try:
    language_to_translate = data_json['language_to_translate']

    if type(language_to_translate) != str:
        raise TypeError("Key 'language_to_translate' is not in correct type 'str'.")
    # Language to translate. If None, you won't translate anything.
    # If you translate, it's a must to load GoogleTranslator frfom deep_translation module
    # Standard: None


    flag_use_chatgpt = data_json['flag_use_chatgpt']

    if type(flag_use_chatgpt) != bool:
        raise TypeError("Key 'flag_use_chatgpt' is not in correct type 'bool'.")
    # Do you want to use chatgpt application?
    # Standard: False


    openai_api_key = data_json['openai_api_key']

    if type(openai_api_key) != str:
        raise TypeError("Key 'openai_api_key' is not in correct type 'str'.")
    # Open AI API key to use chatgpt generate ai.
    # Standard: ''


    flag_fill_phonetic_transc = data_json['flag_fill_phonetic_transc']

    if type(flag_fill_phonetic_transc) != bool:
        raise TypeError("Key 'flag_fill_phonetic_transc' is not in correct type 'bool'.")
    # If you fill the non-found phonetic transcriptions with eng_to_ipa package
    # Standard: False


    trans_word_method = data_json['trans_word_method']

    if type(trans_word_method) != str:
        raise TypeError("Key 'trans_word_method' is not in correct type 'str'.")
    # Parameters for translating examples
    # None: don't translate;
    # 'chatgpt': use chatgpt (don't recommended, translator is enought. 'flag_use_chatgpt = True' is a must.);
    # 'gtrans': use Google Translator package (recommended. 'flag_use_gtrans = True' is a must.).
    # Standard: 'gtrans'


    fill_examples_chatgpt = data_json['fill_examples_chatgpt']

    if type(fill_examples_chatgpt) != str:
        raise TypeError("Key 'fill_examples_chatgpt' is not in correct type 'str'.")
    # Parameters for filling examples that was not found on Longman Dictionary
    # 'phrases': you fill the phrase fill with one example with chat-gpt if there is no other tool to use ('flag_use_chatgpt = True' is a must.;
    # 'all': fill all examples fields with chat-gpt if necessary;
    # None: you don't fill it with chat-gpt.
    # Standard: None


    trans_examples_method = data_json['trans_examples_method']

    if type(fill_examples_chatgpt) != str:
        raise TypeError("Key 'fill_examples_chatgpt' is not in correct type 'str'.")
    # Parameters to translate words inserted
    # None: don't translate;
    # 'chatgpt': use chatgpt (recommended, but it spends tokens. 'flag_use_chatgpt = True' is a must.);
    # 'gtrans': use Google Translator package (don't recommended. 'flag_use_gtrans = True' is a must.).
    # Standard: None


    images_per_noun = data_json['images_per_noun']

    if (type(images_per_noun) != int):
        raise TypeError("Key 'images_per_noun' is not in correct type 'int'.")
    # Words to find the meaning
    # It should be a list (of strings) or a string


    words = data_json['words']

    if (type(words) != list) and (type(words) != str):
        raise TypeError("Key 'words' is not in correct type 'str' or 'list of strings'.")
    # Words to find the meaning
    # It should be a list (of strings) or a string

except KeyError as e:
    print('\nKey ' + str(e) + ' was not found. Application will be closed.')
    time.sleep(5)
    exit()
except TypeError as e:
    print('\n' + str(e) + ' Application will be closed.')
    time.sleep(5)
    exit()

# %%
# Print data
print('\nVariables from ldoceonline_params.json are loaded:\n')
print('- Parameters imported:\n')
print('- language_to_translate: ', language_to_translate)
print('- flag_use_chatgpt: ',flag_use_chatgpt)
print('- openai_api_key: ',openai_api_key)
print('- flag_fill_phonetic_transc: ',flag_fill_phonetic_transc)
print('- trans_word_method: ',trans_word_method)
print('- fill_examples_chatgpt: ',fill_examples_chatgpt)
print('- images_per_noun: ',images_per_noun)
print('- trans_examples_method: ',trans_examples_method)
print('- words: ',words)
# Out:
# Variables from ldoceonline_params.json are loaded:
#
# - Parameters imported:
#
# - language_to_translate:  pt
# - flag_use_chatgpt:  True
# - openai_api_key:  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
# - flag_fill_phonetic_transc:  True
# - trans_word_method:  chatgpt
# - fill_examples_chatgpt:  phrases
# - images_per_noun:  5
# - trans_examples_method:  gtrans
# - words:  ['accent', 'accuracy', 'accurate', 'airborne', 'missile', 'anaconda', 'ankle', 'appetizer', 'appointment', 'assignment', 'baguette', 'bakery', 'bandage', 'bar', 'barefoot', 'basalt', 'behind closed doors', 'bind', 'blow', 'bollywood', 'bracelet', 'branch', 'bricks and mortar', 'bus lane', 'cardio', 'cattle', 'childish', 'chimney', 'chop', 'chopsticks', 'chore', 'chorus', 'circuit training', 'clock', 'watch', 'close down', 'clot', 'coal', 'coarse', 'cockroach', 'coffin', 'commoner', 'commonly', 'concrete', 'conscientious', 'cool down', 'country house', 'croissant', 'cryptocurrency', 'curfew', 'curl', 'cycle lane', 'cylinder', 'dance hall', 'deaf', 'hearing impaired', 'debris', 'decking', 'come-up-with-the-goods-deliver-the-goods', 'diaper', 'din', 'do up', 'dredger', 'dub', 'edge', 'encourage', 'encrypt', 'endeavour', 'envision', 'evolve', 'exploit', 'child labour', 'fancy', 'far sighted', 'fashion', 'fashionable', 'flabby', 'flap', 'fleet', 'flip flops', 'flotilla', 'frame', 'fresh', 'funnel', 'gentle', 'knock-lick-get-somebody-something-into-shape', 'ghetto', 'giraffe', 'go the extra mile', 'governor', 'harvest', 'have ants in your pants', 'have seen better days', 'healthy', 'heater', 'house arrest', 'home office', 'honey', 'hunger', 'hyperopia', 'impregnate', 'be in two minds (about something)', 'inoculate', 'jargon', 'jeopardy', 'keep fit', 'knowledgeable', 'lace up', 'lagoon', 'landlord', 'lawn', 'loaf bread', 'loose', 'medallion', 'melancholy', 'mince', 'mince', 'mob', 'monumental', 'moor', 'mutate', 'myopia', 'nearsighted', 'niche', 'noble', 'nod', 'overturn', 'peasant', 'pesticide', 'picture', 'pin', 'poisonous', 'politician', 'politics', 'pool', 'pork', 'porous', 'permeable', 'pot', 'prejudice', 'probe', 'prophets', 'puppy', 'pushchair', 'push-up', 'python', 'railing', 're-elect', 'reflexology', 'rely', 'rely on/upon', 'remember', 'remind', 'rip off', 'robe', 'roof', 'run over', 'salvage', 'sandbag', 'sausage', 'scarf', 'scholarship', 'seed', 'sensuous', 'shake', 'shanty', 'shrink', 'shutter', 'sight', 'sit up', 'skewness', 'slang', 'slipper', 'slum', 'snooker', 'sort out', 'sought after', 'sow', 'sponsor', 'spoon', 'stack', 'stimulate', 'stream', 'strike', 'stubborn', 'syringe', 'table tennis', 'take your time', 'lane', 'tenant', 'terrace', 'tether', 'thailand', 'thug', 'tin', 'topography', 'tot', 'towel', 'townhouse', 'trailing', 'trip', 'twig', 'unleavened', 'vaccinate', 'vertical', 'vessel', 'vitamin', 'warm up', 'wash up', 'wedge', 'weed', 'trimmer', 'weed trimmer', 'weed wackers', 'wheelchair', 'whim', 'white bread', 'whole grain bread', 'wipe', 'withdraw', 'would rather', 'yeast', 'zinc', 'brown bread', 'the accent is on something', 'ankle socks/boots', 'by appointment to the Queen', 'a wine/coffee/snack etc bar', 'a breakfast bar', 'behind bars', 'bar to (doing) something', 'the bar', 'be called to the bar', 'scroll bar', 'bar none', 'barring', 'be called to the Bar', 'blow your nose', 'blow somebody a kiss', 'blow/blow me/blow it etc', 'blow somebody’s mind', 'blow your top/stack/cool', 'blow the whistle on somebody', 'blow something (up) out of (all) proportion', 'blow your own trumpet', 'blow somebody/something out of the water', 'blow hot and cold', 'blow something sky-high', 'blow down', 'blow in', 'blow out', 'blow over', 'blow up', 'come to blows (with somebody)', 'soften/cushion the blow', 'low blow', 'strike a blow for somebody/something', 'branch off', 'branch out', 'smoke like a chimney', 'chop and change', 'chop at', 'the chop', 'chops', 'the chops', 'a chorus of thanks/disapproval/protest etc', 'in chorus', 'clotted cream', 'carry/take coals to Newcastle', 'haul/rake/drag somebody over the coals', 'make somebody’s hair curl', 'curl up', 'be firing/running on all cylinders', 'be deaf to something', 'turn a deaf ear (to something)', 'fall on deaf ears', 'on edge', 'on the edge of something', 'take the edge off something', 'on the edge of your seat', 'be on the edge', 'cutting edge', 'fancy  ...

# %% [markdown]
# # Pre-definited variables

# %% [markdown]
# Fields of the table:
# - **Word**: the word name with the number if there is duplicates;
# - **Translation**: the translation of the field 'Word', considering the context of the field 'Meaning';
# - **Phonetic_Transcription**: the Phonetic Transcription of this word. The transcription must be between '/'. (Example: /laɪ/);
# - **Meaning**: In original language, not translated, I want the Part of Speech between parenthesis in beggining and after the complete meaning of the word;
# - **Phrase**: In original language, a phrase or sentence about the word, that helps to understand about its meaning. The word itself must be bold in html format;
# - **Translation_Phrase**: the translation of the field 'Phrase'. The translated word itself must be bold in html format;
# - **Example**: In original language, another phrase or sentence about the word, that helps to understand about its meaning. The word itself must be bold in html format;
# - **Translation_Example**: the translation of the field 'Example'. The translated word itself must be bold in html format;
# - **sPhrase**: empty;
# - **sExample**: empty;
# - **Image**: empty;
# - **Tags**: the original language in upper case, and the Part of Speech in lower case. (Example: ENGLISH adjective).

# %%
#   WORDS TO DELETE FROM GRAMMAR KEYS
list_gram_del = ['always','+','adverb/preposition','linking verb',']','[','linking verb']

# COLUMNS NAMES
columns_names = ['ID','word','word_url','Translation','POS','Phonetic_Transcription','Meaning','Phrase','Translation_Phrase','Example','Example_Phrase','sPhrase','sExample','Image','Credits','Tags']

# COLUMNS NAMES
log_columns_names = ['word','order_id','qtd_meanings','qtd_images','new_words_to_search']

# %% [markdown]
# # Functions

# %% [markdown]
# ### Open AI, chatgpt and dall-e functions

# %%
# Check OPEN AI API status
def openai_api_status(module, send_ok_print: bool = True, send_error_print: bool = True):
    try:
        module.Completion.create(model="text-babbage-001", prompt="Test")  # A simple API call to check the key
        if send_ok_print: print('No errors')
        return True
    except Exception as e:
        if send_error_print: print(f"Error: {e}")
        return False

# %%
# Check and retry to check open ai status
def openai_api_check_restart(module, send_ok_print: bool = True, send_error_print: bool = True):
    if not openai_api_status(module, send_ok_print, send_error_print): # First check
        if send_error_print: print('Trying to reconnect with Open AI API.')
        if openai_api_status(module, send_error_print, send_error_print): # Second check
            if send_error_print: print('Open AI API is working.')
            return True
        else:
            if send_error_print: print('Open AI API is not working. Close Open AI application.')
            return False
    else:
        if send_ok_print: print('Open AI API is OK.')
        return True

# %%
# Generate example phrases from word and definition
def chatgpt_get_phrase_from_word(word: str, DEF: str = ''):
    if not openai_api_check_restart(openai, False, True): return '', 0, 0

    content = f"Generate a creative example phrase with \"{word}\".It's '{DEF.split()[0]}' and use its meaning: '{' '.join(DEF.split()[1:])}'."

    price_engine = 0.002 / 1000 # gpt-3.5-turbo costs $ 0.002 por 1,000 tokens at jul, 06 2023

    return_string = ''
    tokens = 0
    price = 0
    i = 0
    while (i <= 2): # loop to attempt to get the word meaning from chatgpt
        try:
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                max_tokens=250,
                n=1,
                temperature=1.0,
                messages=[{"role": "system", "content": content}]
            )
            return_string = response.choices[0].message.content
            i = 3
            tokens = response['usage']['total_tokens']
            price = round(response['usage']['total_tokens'] * price_engine,10)
            time.sleep(2)
        except Exception as e:
            error_text = str(e).strip()[:len('RateLimitError')]
            print(error_text)
            if error_text == 'RateLimitError':
                time.sleep(91)
                i += 1
            else:
                print(f'Error on ChatGPT module: {e}')
                i = 3

    if return_string == '': print('ChatGPT could not to return the phrase by a error process.')

    # Return string, spent tokens and price of tokens   
    return return_string, tokens, price

# %%
# Generate word's translation from word, Part of speech, meaning and language to translate
def chatgpt_translate_word_from_eng(word: str, POS: str, MEANING: str, language: str):
    if not openai_api_check_restart(openai, False, True): return '', 0, 0

    content = f"How do you say '{word}' (part of speech '{POS}' and meaning '{MEANING}') from English to {language}? Return just the saying."

    price_engine = 0.002 / 1000 # gpt-3.5-turbo costs $ 0.002 por 1,000 tokens at jul, 06 2023

    return_string = ''
    tokens = 0
    price = 0
    i = 0
    while (i <= 2): # loop to attempt to get the word meaning from chatgpt
        try:
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                max_tokens=200,
                n=1,
                temperature=0,
                messages=[{"role": "system", "content": content}]
            )
            return_string = response.choices[0].message.content
            i = 3
            tokens = response['usage']['total_tokens']
            price = round(response['usage']['total_tokens'] * price_engine,10)
            time.sleep(2)
        except Exception as e:
            error_text = str(e).strip()[:len('RateLimitError')]
            print(error_text)
            if error_text == 'RateLimitError':
                time.sleep(91)
                i += 1
            else:
                print(f'Error on ChatGPT module: {e}')
                i = 3

    if return_string == '': print('ChatGPT could not to return the translation by a error process.')

    # Return string, spent tokens and price of tokens   
    return return_string, tokens, price

# %%
# Generate word's translation from word, Part of speech, meaning and language to translate
def chatgpt_translate_phrase_from_eng(phrase: str, language: str):
    if not openai_api_check_restart(openai, False, True): return '', 0, 0

    content = f"How do you say the sentence '{phrase}' from English to {language}? Return just the saying."

    price_engine = 0.002 / 1000 # gpt-3.5-turbo costs $ 0.002 por 1,000 tokens at jul, 06 2023

    return_string = ''
    tokens = 0
    price = 0
    i = 0
    while (i <= 2): # loop to attempt to get the word meaning from chatgpt
        try:
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                max_tokens=200,
                n=1,
                temperature=0,
                messages=[{"role": "system", "content": content}]
            )
            return_string = response.choices[0].message.content
            i = 3
            tokens = response['usage']['total_tokens']
            price = round(response['usage']['total_tokens'] * price_engine,10)
            time.sleep(2)
        except Exception as e:
            error_text = str(e).strip()[:len('RateLimitError')]
            print(error_text)
            if error_text == 'RateLimitError':
                time.sleep(91)
                i += 1
            else:
                print(f'Error on ChatGPT module: {e}')
                i = 3

    if return_string == '': print('ChatGPT could not to return the translation by a error process.')              

    # Return string, spent tokens and price of tokens   
    return return_string, tokens, price

# %% [markdown]
# ### Auxiliary functions

# %%
# Clean repetitive words from string
def unique_words_in_string(input_string):
    cleaned_words = []
    for word in input_string.strip().split():
        if word not in cleaned_words: cleaned_words.append(word)
    return ' '.join(cleaned_words)

# %%
# Mark duplicated values from list
def list_mark_duplicates(list: list):
    if not str(type(list)).replace("<class '","").replace("'>","") == 'list': return # Check if it''s a list
    else: return [True if v in list[:i] else False for i, v in enumerate(list)] # Returning

# %%
# Return random values from string
def get_random_values(my_list: list, num_values: int):

    # Generate pseudorandom number
    def generate_pseudo_random(seed):
        return (1103515245 * seed + 12345) % (2**31 - 1)
    
    # Use the hash of the memory address as the seed for the pseudo-random number generator
    seed = hash(id(my_list))

    # Generate a list of num_values pseudo-random indices
    indices = []
    i = 1
    while i <= num_values:
        seed = generate_pseudo_random(seed)
        index = seed % len(my_list)

        if index in indices: continue # Checking repetitive values

        indices.append(index)
        i += 1

    return [my_list[index] for index in indices]

# %%
# Export list to csv
def export_to_csv(data, filename):
    with open(filename, 'w', encoding='utf-8') as file:
        for row in data:
            line = ';'.join('"'+str(value)+'"' for value in row)
            file.write(line + '\n')

# %%
# Remove special characters
def remove_special_characters(string):
    return ''.join([char if ((char.isalnum()) or char == ' ') else '' for char in string])

# %%
# Remove excessive spaces on a string
def remove_excessive_spaces(string : str):
    return ' '.join(string.strip().split())

# %%
# Get formatted time
def get_complete_datetime():
    current_time = time.localtime()
    month = time.strftime("%B", current_time)
    day = time.strftime("%d", current_time)
    year = time.strftime("%Y", current_time)
    hour = time.strftime("%H", current_time)
    minute = time.strftime("%M", current_time)
    
    ordinal_suffix = "th" if 11 <= int(day) <= 13 else {1: "st", 2: "nd", 3: "rd"}.get(int(day) % 10, "th")
    
    return f"{month} {day}{ordinal_suffix}, {year}, {hour}:{minute}"

# %%
# Replace special characters
def replace_special_characters(string : str, replacement : str = ''):
    return ''.join([char if ((char.isalnum()) or char == ' ') else replacement for char in string])

    # special_characters = "!@#$%^&*()[]{};:,./<>?\|`~-=_+’\'\""
    # translation_table = str.maketrans(special_characters, replacement * len(special_characters))
    # return text.translate(translation_table)

# %% [markdown]
# ### Main functions (execution, web scrapping etc.)

# %%
#############################################################################
# FUNCTION: Create the link of the word
def meanings_word_ldoceonline(word, url):

    ########################
    # CONNECT AND GET HTML FROM URL
    response = requests.get(url, headers={
        "User-Agent" : "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"
    })
    soup = BeautifulSoup(response.text, "html.parser")

    list_meaning = []
    list_return_words = []
    list_return_urls = []

    ########################
    # LOOP BY ALL 'DICTENTRY' THAT IS POSSIBLE ON LONGMAN DICTIONARY WORD

    m = 0 # meaning word ID
    total_chatgpt_token = 0
    total_chatgpt_price = 0
    phonetic_transcription = '' # No return from word's phonetic transcription

    count_dictentry = 0
    for dictentry in soup.find_all("span", attrs={"class": "dictentry"}): # Loop in 'dictentry' class
        count_dictentry += 1

    for dictentry in soup.find_all("span", attrs={"class": "dictentry"}): # Loop in 'dictentry' class

        ###########
        # Get subclass 'dictlink'
        dictlink = dictentry.find("span", {"class": "dictlink"})
        if not isinstance(dictlink.find("span", {"class": "ldoceEntry Entry"}), type(None)): subclass = "ldoceEntry Entry"
        elif (count_dictentry == 1) and (not isinstance(dictlink.find("span", {"class": "bussdictEntry Entry"}), type(None))): subclass = "bussdictEntry Entry"
        else: continue
        dict_content = dictlink.find("span", {"class": subclass})

        ###########
        # Get Phonetic Transcription
        phonetic_transcription_html = dict_content.find("span", {"class": 'PronCodes'})
        if not isinstance(phonetic_transcription_html, type(None)): phonetic_transcription = phonetic_transcription_html.text
 
        ###########
        # Get Related Topic
        topic_1_html = dict_content.find("a", {"class": 'topic'})
        if isinstance(topic_1_html, type(None)): topic_str = ''
        else:
            topic_html = topic_1_html.find("a", {"class": 'topic'})
            if isinstance(topic_html, type(None)): topic_str = ''
            else: topic_str = (topic_html.text).lower().replace('topic','').strip()
        
        ###########    
        # Get Part of Speech
        POS_html = dict_content.find("span", {"class": 'POS'})
        if isinstance(POS_html, type(None)): POS_str = 'expression'
        else: POS_str = (POS_html.text).strip()
        
        ###########
        # Get Inflections (Part of Speech)
        Inflections_html = dict_content.find("span", {"class": 'Inflections'})
        if isinstance(Inflections_html, type(None)): Inflections_str = ''
        else: Inflections_str = Inflections_html.text
        
        ###########
        # Get Gramatical classification from POS at all
        Gram_HTML = dict_content.find("span", attrs={"class":"Head"}).find("span", attrs={"class":"GRAM"})
        if isinstance(Gram_HTML, type(None)):
            Gram_tag_gen = ''
            Gram_str_gen = ''
        else:
            Gram_tag_gen = ' '.join([word for word in (Gram_HTML.text).strip().replace(']','').replace('[','').split() if word not in list_gram_del])
            Gram_str_gen = Gram_HTML.text.strip() + ' '

        ###########
        # Word header
        Header_str = (POS_str + ' ' + Inflections_str + ' ' + Gram_str_gen).strip()

        ###########
        # Check dict_content tail
        runon_str = ''
        for TAIL_html in dict_content.find_all("span", attrs={"class":"Tail"}):

            # Get all new words to get in Tail of dictcontext
            if not isinstance(TAIL_html.find("span", attrs={"class":"Crossref"}), type(None)):
                for crossRef_html in TAIL_html.find("span", attrs={"class":"Crossref"}).find_all("a", attrs={"class":"crossRef"}):
                    if word.strip().upper() in crossRef_html.text.upper():
                        list_return_words.append((crossRef_html.get('title')).strip())
                        list_return_urls.append('https://www.ldoceonline.com' + crossRef_html.get('href').strip())  

            # Get derivated words to save on word's meaning: 'RunOn'
            if not isinstance(TAIL_html.find("span", attrs={"class":"RunOn"}), type(None)):
                for RunOn_html in TAIL_html.find_all("span", attrs={"class":"RunOn"}):

                    if isinstance(RunOn_html.find("span", attrs={"class":"DERIV"}), type(None)): text_deriv = ''
                    else: text_deriv = RunOn_html.find("span", attrs={"class":"DERIV"}).text.strip()

                    if isinstance(RunOn_html.find("span", attrs={"class":"POS"}), type(None)): text_POS = ''
                    else: text_POS = RunOn_html.find("span", attrs={"class":"POS"}).text.strip()

                    runon_str += '\n' + ( '— ['+ text_POS + '] ' + text_deriv).strip()
                del RunOn_html, text_deriv, text_POS


        ###########
        # Count the quantity of meanings here
        m_count = 0
        for sense in dict_content.find_all("span", attrs={"class":"Sense"}):
            if isinstance(sense.find("span", attrs={"class":"Crossref"}), type(None)): m_count +=1

        ###########
        # Loop for all senses for the word
        for sense in dict_content.find_all("span", attrs={"class":"Sense"}):
            
            DEF, PURE_DEF, Example_1, Example_2, Example_1_T, Example_2_T = '', '', '', '', '', ''
            TAG = ('English ' + POS_str + ' ' + Gram_tag_gen + ' ' + topic_str).strip()

            # Check if the meaning is just a Crossref to another page
            if not isinstance(sense.find("span", attrs={"class":"Crossref"}), type(None)):

                # If sense refers to a crossref word, get the link to upload its meaning in future loop
                crossRef_html = sense.find("a", attrs={"class":"crossRef"})
                if not isinstance(crossRef_html, type(None)):
                    if word.strip().upper() in crossRef_html.text.upper():
                        list_return_words.append((crossRef_html.get('title')).strip())
                        list_return_urls.append('https://www.ldoceonline.com' + crossRef_html.get('href'))

            if not isinstance(sense.find("span", attrs={"class":"DEF"}), type(None)):

                m += 1 # Add one to meaning ID

                # Get Signpost
                SIGNPOST_html = sense.find("span", attrs={"class":"SIGNPOST"})
                if isinstance(SIGNPOST_html, type(None)): SIGNPOST = ''
                else: 
                    SIGNPOST = (SIGNPOST_html.get_text()).strip().upper()
                    if len(SIGNPOST.replace("/"," ").split()) < 3:
                        TAG = TAG + ' ' + SIGNPOST.replace("/"," ")
                    SIGNPOST = '\n[' + SIGNPOST + ']'

                # Check if the meaning has 'Subsense' to get its meaning and improve TAG values
                if not isinstance(sense.find("span", attrs={"class":"Subsense"}), type(None)):

                    # Loop for all senses for the word
                    for Subsense in sense.find_all("span", attrs={"class":"Subsense"}):

                        # Get sensenum_span
                        NUM_html = Subsense.find("span", attrs={"class":"sensenum span"})
                        if isinstance(NUM_html, type(None)): NUM_str = ''
                        else: NUM_str = NUM_html.text + ' '

                        # Get word definition
                        DEF_html = Subsense.find("span", attrs={"class":"DEF"})
                        if isinstance(DEF_html, type(None)): DEF_str = ''
                        else: DEF_str = DEF_html.text

                        # Get word gramatical substance
                        Gram_HTML = Subsense.find("span", attrs={"class":"GRAM"})
                        if isinstance(Gram_HTML, type(None)): Gram_str = ''
                        else:
                            Gram_tag = ' '.join([word for word in (Gram_HTML.text).strip().replace(']','').replace('[','').split() if word not in list_gram_del])
                            TAG = TAG + ' ' + Gram_tag
                            Gram_str = Gram_HTML.text.strip() + ' '

                        # Get synominous (BREQUIV or SYN)
                        SYN_html = Subsense.find("span", attrs={"class":"BREQUIV"})
                        if isinstance(SYN_html, type(None)):
                            SYN_html = Subsense.find("span", attrs={"class":"SYN"})
                            if isinstance(SYN_html, type(None)): SYN_str = ''
                            else:  SYN_str = ' (' + SYN_html.text.strip() + ')'
                        else: SYN_str = ' (' + SYN_html.text.strip() + ')'

                        # Get geographic reference
                        GEO_html = Subsense.find("span", attrs={"class":"GEO"})
                        if isinstance(GEO_html, type(None)): GEO_str = ''
                        else:
                            TAG = TAG + ' ' + GEO_html.text.lower().replace('english','').strip().capitalize()
                            GEO_str = '[' + GEO_html.text.strip() + '] '

                        # Save word definition var
                        DEF_content = NUM_str + Gram_str + GEO_str + DEF_str.strip().capitalize() + '.' + SYN_str
                        if DEF == '': DEF = Header_str + SIGNPOST + '\n' + DEF_content
                        else: DEF = DEF + ';\n' + DEF_content
                        PURE_DEF +=  ('; ' + DEF_content).strip()

                    # Finish DEF with derivated words
                    DEF += runon_str

                else:
                    # Nulify sensespan_num
                    NUM_str = ''

                    # Get word definition
                    DEF_html = sense.find("span", attrs={"class":"DEF"})
                    if isinstance(DEF_html, type(None)): DEF_str = ''
                    else: DEF_str = DEF_html.text

                    # Get word gramatical substance
                    Gram_HTML = sense.find("span", attrs={"class":"GRAM"})
                    if isinstance(Gram_HTML, type(None)): Gram_str = ''
                    else:
                        Gram_tag = ' '.join([word for word in (Gram_HTML.text).strip().replace(']','').replace('[','').split() if word not in list_gram_del])
                        TAG = TAG + ' ' + Gram_tag
                        Gram_str = Gram_HTML.text.strip() + ' '

                    # Get synominous (BREQUIV or SYN)
                    SYN_html = sense.find("span", attrs={"class":"BREQUIV"})
                    if isinstance(SYN_html, type(None)):
                        SYN_html = sense.find("span", attrs={"class":"SYN"})
                        if isinstance(SYN_html, type(None)): SYN_str = ''
                        else:  SYN_str = ' (' + SYN_html.text.strip() + ')'
                    else: SYN_str = ' (' + SYN_html.text.strip() + ')'

                    # Get geographic reference
                    GEO_html = sense.find("span", attrs={"class":"GEO"})
                    if isinstance(GEO_html, type(None)): GEO_str = ''
                    else:
                        TAG = TAG + ' ' + GEO_html.text.lower().replace('english','').strip().capitalize()
                        GEO_str = '[' + GEO_html.text.strip() + '] '

                    # Save word definition var
                    DEF_content = NUM_str + Gram_str + GEO_str + DEF_str.strip().capitalize() + '.' + SYN_str
                    if DEF == '': DEF = Header_str + SIGNPOST + '\n' + DEF_content
                    else: DEF = DEF + ';\n' + DEF_content
                    PURE_DEF +=  ('; ' + DEF_content).strip()

                    # Finish DEF with derivated words
                    DEF += runon_str

                # Insert examples from sense
                list_examples = [(Example_html.text).strip().capitalize() for Example_html in sense.find_all("span", attrs={"class":"EXAMPLE"})]
                if len(list_examples) > 1: Example_1, Example_2 = get_random_values(list_examples, 2)
                elif len(list_examples) == 1: Example_1, Example_2 = list_examples[0], ''
                del list_examples

                # Fill empty examples
                # With example list of we have just one meaning
                if (m_count == 1) and ((Example_1 == '') or (Example_2 == '')):
                    for ASSETLINK_html in dictentry.find_all("span", attrs={"class":"assetlink"}):
                        if not isinstance(ASSETLINK_html.find("span", attrs={"class":"cexa1g1 exa"}), type(None)):

                            # Insert examples from examples list
                            list_examples = [POSEXAMPLE_html.text.strip().replace('• ','') for POSEXAMPLE_html in ASSETLINK_html.find_all("span", attrs={"class":"cexa1g1 exa"})]
                            if len(list_examples) > 1:
                                if (Example_1 == '') and (Example_2 == ''): Example_1, Example_2 = get_random_values(list_examples, 2)
                                elif Example_1 == '': Example_1 = get_random_values(list_examples, 1)[0]
                                elif Example_2 == '': Example_2 = get_random_values(list_examples, 1)[0]
                            elif len(list_examples) == 1:
                                if Example_1 == '': Example_1 = list_examples[0]
                                elif Example_2 == '': Example_2 = list_examples[0]
                            del list_examples

                # With chatgpt if set
                if global_fexamp_gpt in ['phrases','all']:
                    if Example_1 == '':
                        str_value, token_value, price_value = chatgpt_get_phrase_from_word(word, DEF)
                        Example_1 = str_value
                        total_chatgpt_token += token_value
                        total_chatgpt_price += price_value
                        del str_value, token_value, price_value
                    if (global_fexamp_gpt == 'all') and (Example_2 == ''):
                        str_value, token_value, price_value = chatgpt_get_phrase_from_word(word, DEF)
                        Example_2 = str_value
                        total_chatgpt_token += token_value
                        total_chatgpt_price += price_value
                        del str_value, token_value, price_value

                # Translate examples - use Google Translator or Chat GPT
                if global_texamp == 'gtrans':
                    if Example_1 != '':
                        try:
                            Example_1_T = GoogleTranslator(source='en', target=global_lang_simple).translate(text=Example_1)
                        except Exception as inst:
                            print(f'Error: example {Example_1} was not translated by a error on text itself.')
                            Example_1_T = ''
                    if Example_2 != '':
                        try:
                            Example_2_T = GoogleTranslator(source='en', target=global_lang_simple).translate(text=Example_2)
                        except Exception as inst:
                            print(f'Error: example {Example_2} was not translated by a error on text itself.')
                            Example_2_T = ''
                elif global_texamp == 'chatgpt':
                    if Example_1 != '':
                        str_value, token_value, price_value = chatgpt_translate_phrase_from_eng(word, global_lang_compl)  # Get example's translation from chatgpt
                        Example_1 = str_value
                        total_chatgpt_token += token_value
                        total_chatgpt_price += price_value
                        del str_value, token_value, price_value
                    if Example_2 != '':
                        str_value, token_value, price_value = chatgpt_translate_phrase_from_eng(word, global_lang_compl)  # Get example's translation from chatgpt
                        Example_2 = str_value
                        total_chatgpt_token += token_value
                        total_chatgpt_price += price_value
                        del str_value, token_value, price_value
                
                # Translate word - use Google Translator or Chat GPT
                if global_tword == 'gtrans': Word_T = GoogleTranslator(source='en', target=global_lang_simple).translate(text=word)
                if global_tword == 'chatgpt':
                    str_value, token_value, price_value = chatgpt_translate_word_from_eng(word, POS_str, PURE_DEF, global_lang_compl) # Get word's translation from chatgpt
                    Word_T = str_value.replace('"','').replace("'","").replace(".","")
                    total_chatgpt_token += token_value
                    total_chatgpt_price += price_value
                    del str_value, token_value, price_value
                else: Word_T = ''

                # Adjust phonetic_transcription - use eng_to_ipa package
                if phonetic_transcription == '' and global_phonetic_transc: phon_transc = '/' + eng_to_ipa.convert(word) + '/'
                else: phon_transc = phonetic_transcription

                # Save meanings
                list_meaning.append([replace_special_characters(word).strip().replace(' ','_') + '__' + str(m).zfill(2) + '__' + POS_str.strip().replace(' ','_') # ID
                    ,'to ' + word if POS_str in ['verb','phrasal verb'] else word # Word
                    ,remove_excessive_spaces(replace_special_characters(word.strip()," ")).replace(' ','-').lower() # Word_URL
                    ,Word_T # Translation
                    ,POS_str # POS
                    ,phon_transc # Phonetic transcription
                    ,DEF # Definition
                    ,Example_1 # Phrase
                    ,Example_1_T # Phrase translation
                    ,Example_2 # Example translation
                    ,Example_2_T # Example translation
                    ,'' # Phrase audio
                    ,'' # Example audio
                    ,'' # Image
                    ,global_credits # Credits
                    ,unique_words_in_string(TAG)])               

        m_prev = m # Update m_prev for checking only one meaning applied by 'dictentry'

    return list_meaning, [list_return_words, list_return_urls], total_chatgpt_token, total_chatgpt_price

# %%
#############################################################################
# FUNCTION: GET IMAGES FROM GOOGLE BY WORD

def get_google_images(query: str, img_name: str, images_limit: int):

    # Function to use beautiful soap
    def get_soup(url,header):
        return BeautifulSoup(urllib2.urlopen(urllib2.Request(url,headers=header)))

    # you can change the query for the image  here  
    query = "picture object " + query.lower().strip()
    query= query.split()
    query='+'.join(query)
    url=f"https://www.google.com/search?q={query}&tbm=isch&ved=2ahUKEwjEi-G5-bb_AhUruZUCHeQRALAQ2-cCegQIABAA&oq=sun+glasses&gs_lcp=CgNpbWcQDFAAWABgvFloAHAAeACAAX2IAfUBkgEDMC4ymAEAqgELZ3dzLXdpei1pbWfAAQE&sclient=img&ei=AYGDZISHG6vy1sQP5KOAgAs&bih=833&biw=1745"

    soup = get_soup(url,{'User-Agent': 'Mozilla/5.0'})

    if not os.path.exists(os.getcwd() + "\\" + "ldoceonline_images"): os.makedirs(os.getcwd() + "\\" + "ldoceonline_images")

    images = [a['src'] for a in soup.find_all("img", {"src": re.compile("gstatic.com")})]
    for i, img in enumerate(images):
        if (i + 1) > images_limit: break

        raw_img = urllib2.urlopen(img).read()
        
        DIR = os.getcwd() + "\\" + "ldoceonline_images" # Add the directory for your image here 

        f = open(DIR + "\\" + img_name + '_' + str(i + 1).zfill(2) + '.jpg', 'wb')
        f.write(raw_img)
        f.close()

    return

# %%
#############################################################################
# FUNCTION: LOOP TO GET COMPLETE DEFINITION FROM LONGMAN DICTIONARY
def list_word_ldoceonline(list_words):

    ########################
    # Validate the inputed variable 'list_words'
    type_list_words = str(type(list_words)).replace("<class '","").replace("'>","")
    if type_list_words == 'str':
        list_words = [list_words]
    elif type_list_words == 'list':
        list_words = list(list_words)
        for values in list_words:
            if not str(type(values)).replace("<class '","").replace("'>","") == 'str':
                print("Your list from 'list_words' must have only strings.")
                return []
    else:
        print("'list_words' must be a string or a list.")
        return []
    

    ########################
    # Create lists
    list_words = list((list_words,["https://www.ldoceonline.com/dictionary/" + remove_excessive_spaces(replace_special_characters(word.strip()," ")).replace(' ','-') for word in list_words])) # Add the URL of Longman Dictionary on the list

    list_all_meaning = [] # List empty to get all meaning and examples
    log_list = [] # List empty to get all meaning and examples

    # Clean duplicated words
    list_check_dup = list_mark_duplicates(list_words[0])
    list_words = [[value for value, marked in zip(sublist, list_check_dup) if not marked] for sublist in list_words]


    ########################
    # Loop the values
    print(f'\nStart to search meanings.\n')
    i = 0
    total_chatgpt_token = 0
    total_chatgpt_price = 0
    i_max = len(list_words[0])

    while (i < i_max):

        # Print the current word
        print(f'- Word "{list_words[0][i]}". {i+1} of {(i_max)}.')

        # Get the meaning and examples
        list_1_tmp, list_2_tmp, token_chatgpt, price_chatgpt = meanings_word_ldoceonline(list_words[0][i].strip(),list_words[1][i]) # Get from function meanings and new expressions to find

        # Update lists
        list_all_meaning += list_1_tmp # Save meanings found
        list_words[0] += list_2_tmp[0] # Update new words/expressions to find
        list_words[1] += list_2_tmp[1] # Update their URLs
        total_chatgpt_token += token_chatgpt # Sum of total tokens used from chatgpt
        total_chatgpt_price += price_chatgpt # Sum of total money spent from chatgpt
        
        # Clean duplicated words
        list_check_dup = list_mark_duplicates([word_check.lower() for word_check in list_words[0]])
        list_words = [[value for value, marked in zip(sublist, list_check_dup) if not marked] for sublist in list_words]

        # Print the updates of values
        print(f'{len(list_1_tmp)} meanings from word "{list_words[0][i]}" and {(len(list_words[0]) - i_max)} news words to look for.')

        # Get images to optionally use after on your Anki Cards
        if global_images > 0:
            if 'noun' in [POS[4] for POS in list_1_tmp]:
                qtd_images = global_images
                get_google_images(replace_special_characters(list_words[0][i]).strip().replace(' ','_'), 'img_' + list_words[0][i].strip(), global_images) # generate images to save
                print(str(global_images) + ' images were imported from word ' + list_words[0][i].strip())
            else: qtd_images = 0

        # Update log list
        log_list.append([list_words[0][i], i+1, len(list_1_tmp), qtd_images, (len(list_words[0]) - i_max)])

        # Update temporary variables
        i_max = len(list_words[0])
        i += 1
        del list_1_tmp, list_2_tmp, list_check_dup, token_chatgpt, price_chatgpt


    if total_chatgpt_token > 0: print(f'\nChat GPT spends: {total_chatgpt_token} tokens and {total_chatgpt_price} dolars.')
    print(f'{len(list_all_meaning)} meanings from {len(list_words[0])} words were found and mapped.')
    print(f'\nSearching meanings is finished.')

    ########################
    # Finish the function returning the list
    return list_all_meaning, log_list

# %% [markdown]
# # Apply parameters

# %%
print('\n###################################################################')
print('Import modules according with the parameters:\n')
# Out:
# ###################################################################
# Import modules according with the parameters:

# %%
#### PARAMETER: flag_fill_phonetic_transc -> global_phonetic_transc
global_phonetic_transc = False
text_warning = "\nNo empty phonetic transcription from Longman Dictionary won't be filled."
if flag_fill_phonetic_transc:
    if import_and_check('eng_to_ipa', import_module = True):
        global_phonetic_transc = True
        text_warning = "\neng_to_ipa module will be used to fill empty phonetic transcriptions fields."

print(text_warning)
# Out:
# Library eng_to_ipa is installed and imported.
#
# eng_to_ipa module will be used to fill empty phonetic transcriptions fields.

# %%
#### PARAMETER: flag_use_chatgpt, openai_api -> global_apply_chatgpt
global_apply_chatgpt = False
text_warning = '\nopenai module won\'t be used on this execution.'
if flag_use_chatgpt:
    if import_and_check('openai', import_module = True):
        openai.api_key = openai_api_key # Use chatgpt api key
        if openai_api_check_restart(openai): # Check if chatgpt is working
            global_apply_chatgpt = True
            text_warning = '\nopenai module will be used for Chat GPT applications.'

print(text_warning)
# Out:
# Library openai is installed and imported.
# Error: Error communicating with OpenAI: ('Connection aborted.', ConnectionResetError(10054, 'Foi forçado o cancelamento de uma conexão existente pelo host remoto', None, 10054, None))
# Trying to reconnect with Open AI API.
# No errors
# Open AI API is working.
#
# openai module will be used for Chat GPT applications.

# %%
#### PARAMETER: language_to_translate -> global_apply_trans, global_lang_simple, global_lang_compl, langs_dict
# Load supported languages pack
global_apply_trans = False
global_lang_simple, global_lang_compl = '', ''
text_warning = "\nGoogleTranslator (from deep_translator module) will not be used on this execution."
if not language_to_translate in [None,'']:
    if import_and_check('deep_translator','GoogleTranslator', import_module = True):
        global_apply_trans = True
        text_warning = "\nGoogleTranslator (from deep_translator module) will be used on this execution."

        # List of valid languages
        langs_dict = GoogleTranslator().get_supported_languages(as_dict=True)

        # Confirm language configured
        if language_to_translate not in langs_dict.values(): global_lang_simple = 'pt'
        else: global_lang_simple = language_to_translate

        # Get complete language name
        for key, val in langs_dict.items():
            if val == global_lang_simple:
                global_lang_compl = key.strip()
                break

print(text_warning)
# Out:
# Library deep_translator is installed and imported.
#
# GoogleTranslator (from deep_translator module) will be used on this execution.

# %%
#### PARAMETER: trans_word_method -> global_tword
if (not trans_word_method in ['chatgpt','gtrans']) or (global_apply_trans == False): global_tword = ''
elif trans_word_method == 'chatgpt' and global_apply_chatgpt: global_tword = trans_word_method
elif trans_word_method == 'gtrans': global_tword = trans_word_method
else: global_tword = ''

print('\n' + ('Words will be translated by ChatGPT' if global_tword == 'chatgpt' else 'Words will be translated by Google Translation (not recommended)' if global_tword == 'gtrans' else 'Words won\'t be translated.'))
# Out:
# Words will be translated by ChatGPT

# %%
#### PARAMETER: trans_examples_method -> global_texamp
if (not trans_examples_method in ['chatgpt','gtrans']) or (global_apply_trans == False): global_texamp = ''
elif trans_examples_method == 'chatgpt' and global_apply_chatgpt: global_texamp = trans_examples_method
elif trans_examples_method == 'gtrans': global_texamp = trans_examples_method
else: global_texamp = ''

print('\n' + ('Examples will be translated by ChatGPT' if global_texamp == 'chatgpt' else 'Examples will be translated by Google Translation (not recommended)' if global_texamp == 'gtrans' else 'Examples won\'t be translated.'))
# Out:
# Examples will be translated by Google Translation (not recommended)

# %%
#### PARAMETER: fill_examples_chatgpt -> global_fexamp_gpt
if (not fill_examples_chatgpt in ['phrases','all']) or (global_apply_chatgpt == False): global_fexamp_gpt = ''
else: global_fexamp_gpt = fill_examples_chatgpt

print('\n' + ('Just empty initial phrases (example 1) will be filled by Chat GPT' if global_fexamp_gpt == 'phrases' else 'All empty examples will be filled by Chat GPT' if global_fexamp_gpt == 'all' else 'Examples won\'t be filled if empty.'))
# Out:
# Just empty initial phrases (example 1) will be filled by Chat GPT

# %%
#### PARAMETER: images_per_noun -> global_images
text_warning = "\nImages will not be generated per word."
global_images = 0
if images_per_noun > 0:
     if import_and_check('urllib.request', librename = 'urllib2', import_module = False) and \
        import_and_check('re', import_module = False):
            
            # Import packages for images
            import re
            import urllib.request as urllib2
            print('re and urllib2 were imported.')

            # Update status
            global_images = images_per_noun
            text_warning = '\n' + str(images_per_noun) + " images will be generated per word."

print(text_warning)
# Out:
# Library urllib.request is installed, but it is not imported.
# Library re is installed, but it is not imported.
# re and urllib2 were imported.
#
# 5 images will be generated per word.

# %%
#print(global_phonetic_transc, global_apply_chatgpt, global_apply_trans, global_lang_simple, global_lang_compl, global_tword, global_texamp, global_fexamp_gpt)

# %%
global_credits = 'Word definitions, meanings, and example sentences sourced from ldoceonline.com, by Pearson'
if (global_tword == 'chatgpt') or (global_texamp == 'chatgpt') or (global_fexamp_gpt in ['phrases','all']): 
    global_credits += ';\nadditional information and translation provided by ChatGPT, by OpenAI'
if (global_tword == 'gtrans') or (global_texamp == 'gtrans'):
    global_credits += ';\nother translations was executed by Google Translator, by deep_translator (Nidhal Baccouri) (https://pypi.org/project/deep-translator/)'
if global_phonetic_transc:
    global_credits += ';\nand some phonetic transcriptions were made by eng_to_ipa (https://pypi.org/project/eng-to-ipa/)'
global_credits += '\nWord were taken at ' + get_complete_datetime() + '.'

print('\nCredits:\n' + global_credits + '\n')
# Out:
# Credits:
# Word definitions, meanings, and example sentences sourced from ldoceonline.com, by Pearson;
# additional information and translation provided by ChatGPT, by OpenAI;
# other translations was executed by Google Translator, by deep_translator (Nidhal Baccouri) (https://pypi.org/project/deep-translator/);
# and some phonetic transcriptions were made by eng_to_ipa (https://pypi.org/project/eng-to-ipa/)
# Word were taken at July 01st, 2023, 22:43.

# %% [markdown]
# # Applying model

# %% [markdown]
# ### Input words to translate

# %%
print('\n\n###################################################################')
# Out:
# ###################################################################

# %% [markdown]
# ###  Execute function

# %%
list_ex, log = list_word_ldoceonline(words)
# Out:
# Start to search meanings.
#
# - Word "accent". 1 of 537.
# 5 meanings from word "accent" and -2 news words to look for.
# 5 images were imported from word accent
# - Word "accuracy". 2 of 535.
# 2 meanings from word "accuracy" and 0 news words to look for.
# 5 images were imported from word accuracy
# - Word "accurate". 3 of 535.
# 4 meanings from word "accurate" and 0 news words to look for.
# - Word "airborne". 4 of 535.
# 3 meanings from word "airborne" and 0 news words to look for.
# - Word "missile". 5 of 535.
# 2 meanings from word "missile" and 0 news words to look for.
# 5 images were imported from word missile
# - Word "anaconda". 6 of 535.
# 1 meanings from word "anaconda" and 0 news words to look for.
# 5 images were imported from word anaconda
# - Word "ankle". 7 of 535.
# 1 meanings from word "ankle" and 0 news words to look for.
# 5 images were imported from word ankle
# - Word "appetizer". 8 of 535.
# 1 meanings from word "appetizer" and 0 news words to look for.
# 5 images were imported from word appetizer
# - Word "appointment". 9 of 535.
# 3 meanings from word "appointment" and 0 news words to look for.
# 5 images were imported from word appointment
# - Word "assignment". 10 of 535.
# 4 meanings from word "assignment" and 0 news words to look for.
# 5 images were imported from word assignment
# - Word "baguette". 11 of 535.
# 1 meanings from word "baguette" and 0 news words to look for.
# 5 images were imported from word baguette
# - Word "bakery". 12 of 535.
# 1 meanings from word "bakery" and 0 news words to look for.
# 5 images were imported from word bakery
# - Word "bandage". 13 of 535.
# 2 meanings from word "bandage" and 0 news words to look for.
# 5 images were imported from word bandage
# - Word "bar". 14 of 535.
# 18 meanings from word "bar" and 0 news words to look for.
# 5 images were imported from word bar
# - Word "barefoot". 15 of 535.
# 1 meanings from word "barefoot" and 0 news words to look for.
# - Word "basalt". 16 of 535.
# 1 meanings from word "basalt" and 0 news words to look for.
# 5 images were imported from word basalt
# - Word "behind closed doors". 17 of 535.
# 1 meanings from word "behind closed doors" and 0 news words to look for.
# - Word "bind". 18 of 535.
# 7 meanings from word "bind" and 0 news words to look for.
# 5 images were imported from word bind
# - Word "blow". 19 of 535.
# 14 meanings from word "blow" and 0 news words to look for.
# 5 images were imported from word blow
# - Word "bollywood". 20 of 535.
# 1 meanings from word "bollywood" and 0 news words to look for.
# - Word "bracelet". 21 of 535.
# 1 meanings from word "bracelet" and 0 news words to look for.
# 5 images were imported from word bracelet
# - Word "branch". 22 of 535.
# 7 meanings from word "branch" and 0 news words to look for.
# 5 images were imported from word branch
# - Word "bricks and mortar". 23 of 535.
# 1 meanings from word "bricks and mortar" and 0 news words to look for.
# - Word "bus lane". 24 of 535.
# 1 meanings from word "bus lane" and 0 news words to look for.
# 5 images were imported from word bus lane
# - Word "cardio". 25 of 535.
# 2 meanings from word "cardio" and 0 news words to look for.
# 5 images were imported from word cardio
# - Word "cattle". 26 of 535.
# 1 meanings from word "cattle" and 0 news words to look for.
# 5 images were imported from word cattle
# - Word "childish". 27 of 535.
# 2 meanings from word "childish" and 0 news words to look for.
# - Word "chimney". 28 of 535.
# 3 meanings from word "chimney" and 0 news words to look for.
# 5 images were imported from word chimney
# - Word "chop". 29 of 535.
# 5 meanings from word "chop" and 0 news words to look for.
# 5 images were imported from word chop
# - Word "chopsticks". 30 of 535.
# 1 meanings from word "chopsticks" and 0 news words to look for.
# - Word "chore". 31 of 535.
# 2 meanings from word "chore" and 0 news words to look for.
# 5 images were imported from word chore
# - Word "chorus". 32 of 535.
# 5 meanings from word "chorus" and 0 news words to look for.
# 5 images were imported from word chorus
# - Word "circuit training". 33 of 535.
# 1 meanings from word "circuit training" and 0 news words to look for.
# 5 images were imported from word circuit training
# - Word "clock". 34 of 535.
# 5 meanings from word "clock" and 0 news words to look for.
# 5 images were imported from word clock
# - Word "watch". 35 of 535.
# 9 meanings from word "watch" and 0 news words to look for.
# 5 images were imported from word watch
# - Word "close down". 36 of 535.
# 2 meanings from word "close down" and 0 news words to look for.
# - Word "clot". 37 of 535.
# 3 meanings from word "clot" and 0 news words to look for.
# 5 images were imported from word clot
# - Word "coal". 38 of 535.
# 3 meanings from word "coal" and 0 news words to look for.
# 5 images were imported from word coal
# - Word "coarse". 39 of 535.
# 3 meanings from word "coarse" and 0 news words to look for.
# - Word "cockroach". 40 of 535.
# 1 meanings from word "cockroach" and 0 news words to look for.
# 5 images were imported from word cockroach
# - Word "coffin". 41 of 535.
# 1 meanings from word "coffin" and 1 news words to look for.
# 5 images were imported from word coffin
# - Word "commoner". 42 of 536.
# 1 meanings from word "commoner" and 0 news words to look for.
# 5 images were imported from word commoner
# - Word "commonly". 43 of 536.
# Request timed
# Error on ChatGPT module: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
# ChatGPT could not to return the translation by a error process.
# 2 meanings from word "commonly" and 0 news words to look for.
# - Word "concrete". 44 of 536.
# 4 meanings from word "concrete" and 0 news words to look for.
# 5 images were imported from word concrete
# - Word "conscientious". 45 of 536.
# 1 meanings from word "conscientious" and 0 news words to look for.
# - Word "cool down". 46 of 536.
# 2 meanings from word "cool down" and 0 news words to look for.
# - Word "country house". 47 of 536.
# 1 meanings from word "country house" and 0 news words to look for.
# 5 images were imported from word country house
# - Word "croissant". 48 of 536.
# 1 meanings from word "croissant" and 0 news words to look for.
# 5 images were imported from word croissant
# - Word "cryptocurrency". 49 of 536.
# 0 meanings from word "cryptocurrency" and 0 news words to look for.
# - Word "curfew". 50 of 536.
# 2 meanings from word "curfew" and 0 news words to look for.
# 5 images were imported from word curfew
# - Word "curl". 51 of 536.
# 7 meanings from word "curl" and 1 news words to look for.
# 5 images were imported from word curl
# - Word "cycle lane". 52 of 537.
# 1 meanings from word "cycle lane" and 0 news words to look for.
# 5 images were imported from word cycle lane
# - Word "cylinder". 53 of 537.
# 2 meanings from word "cylinder" and 0 news words to look for.
# 5 images were imported from word cylinder
# - Word "dance hall". 54 of 537.
# 1 meanings from word "dance hall" and 0 news words to look for.
# 5 images were imported from word dance hall
# - Word "deaf". 55 of 537.
# 1 meanings from word "deaf" and 0 news words to look for.
# - Word "hearing impaired". 56 of 537.
# 1 meanings from word "hearing impaired" and 0 news words to look for.
# - Word "debris". 57 of 537.
# 2 meanings from word "debris" and 0 news words to look for.
# 5 images were imported from word debris
# - Word "decking". 58 of 537.
# 1 meanings from word "decking" and 0 news words to look for.
# 5 images were imported from word decking
# - Word "come-up-with-the-goods-deliver-the-goods". 59 of 537.
# 1 meanings from word "come-up-with-the-goods-deliver-the-goods" and 0 news words to look for.
# - Word "diaper". 60 of 537.
# 1 meanings from word "diaper" and 0 news words to look for.
# 5 images were imported from word diaper
# - Word "din". 61 of 537.
# 1 meanings from word "din" and 0 news words to look for.
# 5 images were imported from word din
# - Word "do up". 62 of 537.
# 5 meanings from word "do up" and 0 news words to look for.
# - Word "dredger". 63 of 537.
# 1 meanings from word "dredger" and 0 news words to look for.
# 5 images were imported from word dredger
# - Word "dub". 64 of 537.
# 6 meanings from word "dub" and 0 news words to look for.
# 5 images were imported from word dub
# - Word "edge". 65 of 537.
# 10 meanings from word "edge" and 0 news words to look for.
# 5 images were imported from word edge
# - Word "encourage". 66 of 537.
# 3 meanings from word "encourage" and 0 news words to look for.
# - Word "encrypt". 67 of 537.
# 1 meanings from word "encrypt" and 0 news words to look for.
# - Word "endeavour". 68 of 537.
# 2 meanings from word "endeavour" and 0 news words to look for.
# 5 images were imported from word endeavour
# - Word "envision". 69 of 537.
# 1 meanings from word "envision" and 0 news words to look for.
# - Word "evolve". 70 of 537.
# 2 meanings from word "evolve" and 0 news words to look for.
# - Word "exploit". 71 of 537.
# 5 meanings from word "exploit" and 0 news words to look for.
# 5 images were imported from word exploit
# - Word "child labour". 72 of 537.
# 1 meanings from word "child labour" and 0 news words to look for.
# - Word "fancy". 73 of 537.
# 11 meanings from word "fancy" and 1 news words to look for.
# 5 images were imported from word fancy
# - Word "far sighted". 74 of 538.
# 2 meanings from word "far sighted" and 0 news words to look for.
# - Word "fashion". 75 of 538.
# 6 meanings from word "fashion" and 0 news words to look for.
# 5 images were imported from word fashion
# - Word "fashionable". 76 of 538.
# 2 meanings from word "fashionable" and 0 news words to look for.
# - Word "flabby". 77 of 538.
# 2 meanings from word "flabby" and 0 news words to look for.
# - Word "flap". 78 of 538.
# 6 meanings from word "flap" and 0 news words to look for.
# 5 images were imported from word flap
# - Word "fleet". 79 of 538.
# 3 meanings from word "fleet" and 0 news words to look for.
# 5 images were imported from word fleet
# - Word "flip flops". 80 of 538.
# 1 meanings from word "flip flops" and 0 news words to look for.
# 5 images were imported from word flip flops
# - Word "flotilla". 81 of 538.
# 1 meanings from word "flotilla" and 0 news words to look for.
# 5 images were imported from word flotilla
# - Word "frame". 82 of 538.
# 13 meanings from word "frame" and 0 news words to look for.
# 5 images were imported from word frame
# - Word "fresh". 83 of 538.
# 8 meanings from word "fresh" and 0 news words to look for.
# - Word "funnel". 84 of 538.
# 4 meanings from word "funnel" and 0 news words to look for.
# 5 images were imported from word funnel
# - Word "gentle". 85 of 538.
# 4 meanings from word "gentle" and 0 news words to look for.
# - Word "knock-lick-get-somebody-something-into-shape". 86 of 538.
# 1 meanings from word "knock-lick-get-somebody-something-into-shape" and 0 news words to look for.
# - Word "ghetto". 87 of 538.
# 2 meanings from word "ghetto" and 0 news words to look for.
# 5 images were imported from word ghetto
# - Word "giraffe". 88 of 538.
# Request timed
# Error on ChatGPT module: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
# ChatGPT could not to return the translation by a error process.
# 1 meanings from word "giraffe" and 0 news words to look for.
# 5 images were imported from word giraffe
# - Word "go the extra mile". 89 of 538.
# 1 meanings from word "go the extra mile" and 0 news words to look for.
# - Word "governor". 90 of 538.
# 4 meanings from word "governor" and 0 news words to look for.
# 5 images were imported from word governor
# - Word "harvest". 91 of 538.
# 4 meanings from word "harvest" and 0 news words to look for.
# 5 images were imported from word harvest
# - Word "have ants in your pants". 92 of 538.
# 1 meanings from word "have ants in your pants" and 0 news words to look for.
# - Word "have seen better days". 93 of 538.
# 1 meanings from word "have seen better days" and 0 news words to look for.
# - Word "healthy". 94 of 538.
# 6 meanings from word "healthy" and 0 news words to look for.
# - Word "heater". 95 of 538.
# 1 meanings from word "heater" and 0 news words to look for.
# 5 images were imported from word heater
# - Word "house arrest". 96 of 538.
# 0 meanings from word "house arrest" and 0 news words to look for.
# - Word "home office". 97 of 538.
# 2 meanings from word "home office" and 0 news words to look for.
# 5 images were imported from word home office
# - Word "honey". 98 of 538.
# 3 meanings from word "honey" and 0 news words to look for.
# 5 images were imported from word honey
# - Word "hunger". 99 of 538.
# 3 meanings from word "hunger" and 0 news words to look for.
# 5 images were imported from word hunger
# - Word "hyperopia". 100 of 538.
# 0 meanings from word "hyperopia" and 0 news words to look for.
# - Word "impregnate". 101 of 538.
# 2 meanings from word "impregnate" and 0 news words to look for.
# - Word "be in two minds (about something)". 102 of 538.
# 1 meanings from word "be in two minds (about something)" and 0 news words to look for.
# - Word "inoculate". 103 of 538.
# 1 meanings from word "inoculate" and 0 news words to look for.
# - Word "jargon". 104 of 538.
# 1 meanings from word "jargon" and 0 news words to look for.
# 5 images were imported from word jargon
# - Word "jeopardy". 105 of 538.
# 0 meanings from word "jeopardy" and 0 news words to look for.
# - Word "keep fit". 106 of 538.
# 1 meanings from word "keep fit" and 0 news words to look for.
# 5 images were imported from word keep fit
# - Word "knowledgeable". 107 of 538.
# 1 meanings from word "knowledgeable" and 0 news words to look for.
# - Word "lace up". 108 of 538.
# 1 meanings from word "lace up" and 0 news words to look for.
# 5 images were imported from word lace up
# - Word "lagoon". 109 of 538.
# 2 meanings from word "lagoon" and 0 news words to look for.
# 5 images were imported from word lagoon
# - Word "landlord". 110 of 538.
# 2 meanings from word "landlord" and 0 news words to look for.
# 5 images were imported from word landlord
# - Word "lawn". 111 of 538.
# 2 meanings from word "lawn" and 0 news words to look for.
# 5 images were imported from word lawn
# - Word "loaf bread". 112 of 538.
# 0 meanings from word "loaf bread" and 0 news words to look for.
# - Word "loose". 113 of 538.
# 16 meanings from word "loose" and 1 news words to look for.
# - Word "medallion". 114 of 539.
# 1 meanings from word "medallion" and 0 news words to look for.
# 5 images were imported from word medallion
# - Word "melancholy". 115 of 539.
# 2 meanings from word "melancholy" and 0 news words to look for.
# 5 images were imported from word melancholy
# - Word "mince". 116 of 539.
# 3 meanings from word "mince" and 0 news words to look for.
# 5 images were imported from word mince
# - Word "mob". 117 of 539.
# 4 meanings from word "mob" and 0 news words to look for.
# 5 images were imported from word mob
# - Word "monumental". 118 of 539.
# 3 meanings from word "monumental" and 0 news words to look for.
# - Word "moor". 119 of 539.
# 3 meanings from word "moor" and 0 news words to look for.
# 5 images were imported from word moor
# - Word "mutate". 120 of 539.
# 2 meanings from word "mutate" and 0 news words to look for.
# - Word "myopia". 121 of 539.
# 2 meanings from word "myopia" and 0 news words to look for.
# 5 images were imported from word myopia
# - Word "nearsighted". 122 of 539.
# 1 meanings from word "nearsighted" and 0 news words to look for.
# - Word "niche". 123 of 539.
# 4 meanings from word "niche" and 0 news words to look for.
# 5 images were imported from word niche
# - Word "noble". 124 of 539.
# 4 meanings from word "noble" and 0 news words to look for.
# 5 images were imported from word noble
# - Word "nod". 125 of 539.
# 3 meanings from word "nod" and 0 news words to look for.
# 5 images were imported from word nod
# - Word "overturn". 126 of 539.
# 2 meanings from word "overturn" and 0 news words to look for.
# - Word "peasant". 127 of 539.
# 2 meanings from word "peasant" and 0 news words to look for.
# 5 images were imported from word peasant
# - Word "pesticide". 128 of 539.
# 1 meanings from word "pesticide" and 0 news words to look for.
# 5 images were imported from word pesticide
# - Word "picture". 129 of 539.
# 10 meanings from word "picture" and 0 news words to look for.
# 5 images were imported from word picture
# - Word "pin". 130 of 539.
# 9 meanings from word "pin" and 0 news words to look for.
# 5 images were imported from word pin
# - Word "poisonous". 131 of 539.
# 3 meanings from word "poisonous" and 0 news words to look for.
# - Word "politician". 132 of 539.
# 2 meanings from word "politician" and 0 news words to look for.
# 5 images were imported from word politician
# - Word "politics". 133 of 539.
# 5 meanings from word "politics" and 0 news words to look for.
# 5 images were imported from word politics
# - Word "pool". 134 of 539.
# 7 meanings from word "pool" and 0 news words to look for.
# 5 images were imported from word pool
# - Word "pork". 135 of 539.
# 2 meanings from word "pork" and 0 news words to look for.
# 5 images were imported from word pork
# - Word "porous". 136 of 539.
# 2 meanings from word "porous" and 0 news words to look for.
# - Word "permeable". 137 of 539.
# 1 meanings from word "permeable" and 0 news words to look for.
# - Word "pot". 138 of 539.
# 11 meanings from word "pot" and 0 news words to look for.
# 5 images were imported from word pot
# - Word "prejudice". 139 of 539.
# 4 meanings from word "prejudice" and 0 news words to look for.
# 5 images were imported from word prejudice
# - Word "probe". 140 of 539.
# 5 meanings from word "probe" and 0 news words to look for.
# 5 images were imported from word probe
# - Word "prophets". 141 of 539.
# 2 meanings from word "prophets" and 0 news words to look for.
# - Word "puppy". 142 of 539.
# 1 meanings from word "puppy" and 0 news words to look for.
# 5 images were imported from word puppy
# - Word "pushchair". 143 of 539.
# 1 meanings from word "pushchair" and 0 news words to look for.
# 5 images were imported from word pushchair
# - Word "push-up". 144 of 539.
# 1 meanings from word "push-up" and 0 news words to look for.
# 5 images were imported from word push-up
# - Word "python". 145 of 539.
# 1 meanings from word "python" and 0 news words to look for.
# 5 images were imported from word python
# - Word "railing". 146 of 539.
# 2 meanings from word "railing" and 0 news words to look for.
# 5 images were imported from word railing
# - Word "re-elect". 147 of 539.
# 1 meanings from word "re-elect" and 0 news words to look for.
# - Word "reflexology". 148 of 539.
# 1 meanings from word "reflexology" and 0 news words to look for.
# 5 images were imported from word reflexology
# - Word "rely". 149 of 539.
# 0 meanings from word "rely" and 0 news words to look for.
# - Word "rely on/upon". 150 of 539.
# Request timed
# Error on ChatGPT module: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
# ChatGPT could not to return the translation by a error process.
# 2 meanings from word "rely on/upon" and 0 news words to look for.
# - Word "remember". 151 of 539.
# 6 meanings from word "remember" and 0 news words to look for.
# - Word "remind". 152 of 539.
# 2 meanings from word "remind" and 0 news words to look for.
# - Word "rip off". 153 of 539.
# 5 meanings from word "rip off" and 0 news words to look for.
# 5 images were imported from word rip off
# - Word "robe". 154 of 539.
# 2 meanings from word "robe" and 0 news words to look for.
# 5 images were imported from word robe
# - Word "roof". 155 of 539.
# 3 meanings from word "roof" and 0 news words to look for.
# 5 images were imported from word roof
# - Word "run over". 156 of 539.
# 5 meanings from word "run over" and 0 news words to look for.
# - Word "salvage". 157 of 539.
# 4 meanings from word "salvage" and 0 news words to look for.
# 5 images were imported from word salvage
# - Word "sandbag". 158 of 539.
# 3 meanings from word "sandbag" and 0 news words to look for.
# 5 images were imported from word sandbag
# - Word "sausage". 159 of 539.
# 1 meanings from word "sausage" and 0 news words to look for.
# 5 images were imported from word sausage
# - Word "scarf". 160 of 539.
# 2 meanings from word "scarf" and 0 news words to look for.
# 5 images were imported from word scarf
# - Word "scholarship". 161 of 539.
# 2 meanings from word "scholarship" and 0 news words to look for.
# 5 images were imported from word scholarship
# - Word "seed". 162 of 539.
# 8 meanings from word "seed" and 0 news words to look for.
# 5 images were imported from word seed
# - Word "sensuous". 163 of 539.
# 2 meanings from word "sensuous" and 0 news words to look for.
# - Word "shake". 164 of 539.
# 5 meanings from word "shake" and 0 news words to look for.
# 5 images were imported from word shake
# - Word "shanty". 165 of 539.
# 2 meanings from word "shanty" and 0 news words to look for.
# 5 images were imported from word shanty
# - Word "shrink". 166 of 539.
# 4 meanings from word "shrink" and 0 news words to look for.
# 5 images were imported from word shrink
# - Word "shutter". 167 of 539.
# 3 meanings from word "shutter" and 0 news words to look for.
# 5 images were imported from word shutter
# - Word "sight". 168 of 539.
# 5 meanings from word "sight" and 1 news words to look for.
# 5 images were imported from word sight
# - Word "sit up". 169 of 540.
# 6 meanings from word "sit up" and 0 news words to look for.
# 5 images were imported from word sit up
# - Word "skewness". 170 of 540.
# 0 meanings from word "skewness" and 0 news words to look for.
# - Word "slang". 171 of 540.
# 1 meanings from word "slang" and 0 news words to look for.
# 5 images were imported from word slang
# - Word "slipper". 172 of 540.
# 1 meanings from word "slipper" and 0 news words to look for.
# 5 images were imported from word slipper
# - Word "slum". 173 of 540.
# 2 meanings from word "slum" and 0 news words to look for.
# 5 images were imported from word slum
# - Word "snooker". 174 of 540.
# 2 meanings from word "snooker" and 0 news words to look for.
# 5 images were imported from word snooker
# - Word "sort out". 175 of 540.
# 7 meanings from word "sort out" and 0 news words to look for.
# 5 images were imported from word sort out
# - Word "sought after". 176 of 540.
# 1 meanings from word "sought after" and 0 news words to look for.
# - Word "sow". 177 of 540.
# 3 meanings from word "sow" and 0 news words to look for.
# 5 images were imported from word sow
# - Word "sponsor". 178 of 540.
# 9 meanings from word "sponsor" and 0 news words to look for.
# 5 images were imported from word sponsor
# - Word "spoon". 179 of 540.
# 3 meanings from word "spoon" and 0 news words to look for.
# 5 images were imported from word spoon
# - Word "stack". 180 of 540.
# 4 meanings from word "stack" and 1 news words to look for.
# 5 images were imported from word stack
# - Word "stimulate". 181 of 541.
# 3 meanings from word "stimulate" and 0 news words to look for.
# - Word "stream". 182 of 541.
# 11 meanings from word "stream" and 0 news words to look for.
# 5 images were imported from word stream
# - Word "strike". 183 of 541.
# 15 meanings from word "strike" and 0 news words to look for.
# 5 images were imported from word strike
# - Word "stubborn". 184 of 541.
# 2 meanings from word "stubborn" and 0 news words to look for.
# - Word "syringe". 185 of 541.
# 2 meanings from word "syringe" and 0 news words to look for.
# 5 images were imported from word syringe
# - Word "table tennis". 186 of 541.
# 1 meanings from word "table tennis" and 0 news words to look for.
# 5 images were imported from word table tennis
# - Word "take your time". 187 of 541.
# 1 meanings from word "take your time" and 0 news words to look for.
# - Word "lane". 188 of 541.
# 5 meanings from word "lane" and 2 news words to look for.
# 5 images were imported from word lane
# - Word "tenant". 189 of 543.
# 1 meanings from word "tenant" and 0 news words to look for.
# 5 images were imported from word tenant
# - Word "terrace". 190 of 543.
# 3 meanings from word "terrace" and 0 news words to look for.
# 5 images were imported from word terrace
# - Word "tether". 191 of 543.
# 3 meanings from word "tether" and 0 news words to look for.
# 5 images were imported from word tether
# - Word "thailand". 192 of 543.
# 1 meanings from word "thailand" and 0 news words to look for.
# - Word "thug". 193 of 543.
# 1 meanings from word "thug" and 0 news words to look for.
# 5 images were imported from word thug
# - Word "tin". 194 of 543.
# 6 meanings from word "tin" and 0 news words to look for.
# 5 images were imported from word tin
# - Word "topography". 195 of 543.
# 2 meanings from word "topography" and 0 news words to look for.
# 5 images were imported from word topography
# - Word "tot". 196 of 543.
# 2 meanings from word "tot" and 0 news words to look for.
# 5 images were imported from word tot
# - Word "towel". 197 of 543.
# 2 meanings from word "towel" and 0 news words to look for.
# 5 images were imported from word towel
# - Word "townhouse". 198 of 543.
# 3 meanings from word "townhouse" and 0 news words to look for.
# 5 images were imported from word townhouse
# - Word "trailing". 199 of 543.
# 1 meanings from word "trailing" and 0 news words to look for.
# - Word "trip". 200 of 543.
# 9 meanings from word "trip" and 0 news words to look for.
# 5 images were imported from word trip
# - Word "twig". 201 of 543.
# 2 meanings from word "twig" and 0 news words to look for.
# 5 images were imported from word twig
# - Word "unleavened". 202 of 543.
# 1 meanings from word "unleavened" and 0 news words to look for.
# - Word "vaccinate". 203 of 543.
# 1 meanings from word "vaccinate" and 0 news words to look for.
# - Word "vertical". 204 of 543.
# 2 meanings from word "vertical" and 0 news words to look for.
# - Word "vessel". 205 of 543.
# 3 meanings from word "vessel" and 0 news words to look for.
# 5 images were imported from word vessel
# - Word "vitamin". 206 of 543.
# 2 meanings from word "vitamin" and 0 news words to look for.
# 5 images were imported from word vitamin
# - Word "warm up". 207 of 543.
# 12 meanings from word "warm up" and 0 news words to look for.
# 5 images were imported from word warm up
# - Word "wash up". 208 of 543.
# 4 meanings from word "wash up" and 0 news words to look for.
# 5 images were imported from word wash up
# - Word "wedge". 209 of 543.
# 3 meanings from word "wedge" and 0 news words to look for.
# 5 images were imported from word wedge
# - Word "weed". 210 of 543.
# 5 meanings from word "weed" and 0 news words to look for.
# 5 images were imported from word weed
# - Word "trimmer". 211 of 543.
# 1 meanings from word "trimmer" and 0 news words to look for.
# 5 images were imported from word trimmer
# - Word "weed trimmer". 212 of 543.
# 0 meanings from word "weed trimmer" and 0 news words to look for.
# - Word "weed wackers". 213 of 543.
# 0 meanings from word "weed wackers" and 0 news words to look for.
# - Word "wheelchair". 214 of 543.
# 1 meanings from word "wheelchair" and 0 news words to look for.
# 5 images were imported from word wheelchair
# - Word "whim". 215 of 543.
# 1 meanings from word "whim" and 0 news words to look for.
# 5 images were imported from word whim
# - Word "white bread". 216 of 543.
# 1 meanings from word "white bread" and 0 news words to look for.
# - Word "whole grain bread". 217 of 543.
# 0 meanings from word "whole grain bread" and 0 news words to look for.
# - Word "wipe". 218 of 543.
# 6 meanings from word "wipe" and 0 news words to look for.
# 5 images were imported from word wipe
# - Word "withdraw". 219 of 543.
# 10 meanings from word "withdraw" and 0 news words to look for.
# - Word "would rather". 220 of 543.
# 1 meanings from word "would rather" and 0 news words to look for.
# - Word "yeast". 221 of 543.
# 1 meanings from word "yeast" and 0 news words to look for.
# 5 images were imported from word yeast
# - Word "zinc". 222 of 543.
# 1 meanings from word "zinc" and 0 news words to look for.
# 5 images were imported from word zinc
# - Word "brown bread". 223 of 543.
# 0 meanings from word "brown bread" and 0 news words to look for.
# - Word "the accent is on something". 224 of 543.
# 1 meanings from word "the accent is on something" and 0 news words to look for.
# - Word "ankle socks/boots". 225 of 543.
# 1 meanings from word "ankle socks/boots" and 0 news words to look for.
# - Word "by appointment to the Queen". 226 of 543.
# 1 meanings from word "by appointment to the Queen" and 0 news words to look for.
# - Word "a wine/coffee/snack etc bar". 227 of 543.
# 1 meanings from word "a wine/coffee/snack etc bar" and 0 news words to look for.
# - Word "a breakfast bar". 228 of 543.
# 1 meanings from word "a breakfast bar" and 0 news words to look for.
# - Word "behind bars". 229 of 543.
# 1 meanings from word "behind bars" and 0 news words to look for.
# - Word "bar to (doing) something". 230 of 543.
# 1 meanings from word "bar to (doing) something" and 0 news words to look for.
# - Word "the bar". 231 of 543.
# 1 meanings from word "the bar" and 0 news words to look for.
# - Word "be called to the bar". 232 of 543.
# 2 meanings from word "be called to the bar" and 0 news words to look for.
# - Word "scroll bar". 233 of 543.
# 1 meanings from word "scroll bar" and 0 news words to look for.
# 5 images were imported from word scroll bar
# - Word "bar none". 234 of 543.
# 1 meanings from word "bar none" and 0 news words to look for.
# - Word "barring". 235 of 543.
# 1 meanings from word "barring" and 0 news words to look for.
# - Word "blow your nose". 236 of 543.
# 1 meanings from word "blow your nose" and 0 news words to look for.
# - Word "blow somebody a kiss". 237 of 543.
# 1 meanings from word "blow somebody a kiss" and 0 news words to look for.
# - Word "blow/blow me/blow it etc". 238 of 543.
# 1 meanings from word "blow/blow me/blow it etc" and 0 news words to look for.
# - Word "blow somebody’s mind". 239 of 543.
# 1 meanings from word "blow somebody’s mind" and 0 news words to look for.
# - Word "blow your top/stack/cool". 240 of 543.
# 1 meanings from word "blow your top/stack/cool" and 0 news words to look for.
# - Word "blow the whistle on somebody". 241 of 543.
# 1 meanings from word "blow the whistle on somebody" and 0 news words to look for.
# - Word "blow something (up) out of (all) proportion". 242 of 543.
# 1 meanings from word "blow something (up) out of (all) proportion" and 0 news words to look for.
# - Word "blow your own trumpet". 243 of 543.
# 1 meanings from word "blow your own trumpet" and 0 news words to look for.
# - Word "blow somebody/something out of the water". 244 of 543.
# 1 meanings from word "blow somebody/something out of the water" and 0 news words to look for.
# - Word "blow hot and cold". 245 of 543.
# 1 meanings from word "blow hot and cold" and 0 news words to look for.
# - Word "blow something sky-high". 246 of 543.
# 2 meanings from word "blow something sky-high" and 0 news words to look for.
# - Word "blow down". 247 of 543.
# 1 meanings from word "blow down" and 0 news words to look for.
# - Word "blow in". 248 of 543.
# 2 meanings from word "blow in" and 0 news words to look for.
# - Word "blow out". 249 of 543.
# 8 meanings from word "blow out" and 0 news words to look for.
# - Word "blow over". 250 of 543.
# 3 meanings from word "blow over" and 0 news words to look for.
# - Word "blow up". 251 of 543.
# 9 meanings from word "blow up" and 0 news words to look for.
# 5 images were imported from word blow up
# - Word "come to blows (with somebody)". 252 of 543.
# 1 meanings from word "come to blows (with somebody)" and 0 news words to look for.
# - Word "soften/cushion the blow". 253 of 543.
# 1 meanings from word "soften/cushion the blow" and 0 news words to look for.
# - Word "low blow". 254 of 543.
# 1 meanings from word "low blow" and 0 news words to look for.
# - Word "strike a blow for somebody/something". 255 of 543.
# 1 meanings from word "strike a blow for somebody/something" and 0 news words to look for.
# - Word "branch off". 256 of 543.
# 3 meanings from word "branch off" and 0 news words to look for.
# - Word "branch out". 257 of 543.
# 1 meanings from word "branch out" and 0 news words to look for.
# - Word "smoke like a chimney". 258 of 543.
# 1 meanings from word "smoke like a chimney" and 0 news words to look for.
# - Word "chop and change". 259 of 543.
# 1 meanings from word "chop and change" and 0 news words to look for.
# - Word "chop at". 260 of 543.
# 1 meanings from word "chop at" and 0 news words to look for.
# - Word "the chop". 261 of 543.
# 1 meanings from word "the chop" and 0 news words to look for.
# - Word "chops". 262 of 543.
# 1 meanings from word "chops" and 0 news words to look for.
# - Word "the chops". 263 of 543.
# 1 meanings from word "the chops" and 0 news words to look for.
# - Word "a chorus of thanks/disapproval/protest etc". 264 of 543.
# 1 meanings from word "a chorus of thanks/disapproval/protest etc" and 0 news words to look for.
# - Word "in chorus". 265 of 543.
# 1 meanings from word "in chorus" and 0 news words to look for.
# - Word "clotted cream". 266 of 543.
# 1 meanings from word "clotted cream" and 0 news words to look for.
# 5 images were imported from word clotted cream
# - Word "carry/take coals to Newcastle". 267 of 543.
# 1 meanings from word "carry/take coals to Newcastle" and 0 news words to look for.
# - Word "haul/rake/drag somebody over the coals". 268 of 543.
# 1 meanings from word "haul/rake/drag somebody over the coals" and 0 news words to look for.
# - Word "make somebody’s hair curl". 269 of 543.
# 1 meanings from word "make somebody’s hair curl" and 0 news words to look for.
# - Word "curl up". 270 of 543.
# 2 meanings from word "curl up" and 0 news words to look for.
# - Word "be firing/running on all cylinders". 271 of 543.
# 1 meanings from word "be firing/running on all cylinders" and 0 news words to look for.
# - Word "be deaf to something". 272 of 543.
# 1 meanings from word "be deaf to something" and 0 news words to look for.
# - Word "turn a deaf ear (to something)". 273 of 543.
# 1 meanings from word "turn a deaf ear (to something)" and 0 news words to look for.
# - Word "fall on deaf ears". 274 of 543.
# 1 meanings from word "fall on deaf ears" and 0 news words to look for.
# - Word "on edge". 275 of 543.
# 1 meanings from word "on edge" and 0 news words to look for.
# - Word "on the edge of something". 276 of 543.
# 1 meanings from word "on the edge of something" and 0 news words to look for.
# - Word "take the edge off something". 277 of 543.
# 1 meanings from word "take the edge off something" and 0 news words to look for.
# - Word "on the edge of your seat". 278 of 543.
# 2 meanings from word "on the edge of your seat" and 0 news words to look for.
# - Word "be on the edge". 279 of 543.
# 1 meanings from word "be on the edge" and 0 news words to look for.
# - Word "cutting edge". 280 of 543.
# 1 meanings from word "cutting edge" and 0 news words to look for.
# 5 images were imported from word cutting edge
# - Word "fancy yourself". 281 of 543.
# 1 meanings from word "fancy yourself" and 0 news words to look for.
# - Word "fancy yourself (as) something". 282 of 543.
# 1 meanings from word "fancy yourself (as) something" and 0 news words to look for.
# - Word "fancy!/fancy that!". 283 of 543.
# 1 meanings from word "fancy!/fancy that!" and 0 news words to look for.
# - Word "flight of fancy/imagination/fantasy". 284 of 543.
# 1 meanings from word "flight of fancy/imagination/fantasy" and 0 news words to look for.
# - Word "in a fashion". 285 of 543.
# 1 meanings from word "in a fashion" and 0 news words to look for.
# - Word "after a fashion". 286 of 543.
# 1 meanings from word "after a fashion" and 0 news words to look for.
# - Word "after the fashion of somebody". 287 of 543.
# 1 meanings from word "after the fashion of somebody" and 0 news words to look for.
# - Word "parrot fashion". 288 of 543.
# 1 meanings from word "parrot fashion" and 0 news words to look for.
# - Word "be in/out of the frame (for something)". 289 of 543.
# 1 meanings from word "be in/out of the frame (for something)" and 0 news words to look for.
# - Word "climbing frame". 290 of 543.
# 1 meanings from word "climbing frame" and 0 news words to look for.
# 5 images were imported from word climbing frame
# - Word "cold frame". 291 of 543.
# 1 meanings from word "cold frame" and 0 news words to look for.
# 5 images were imported from word cold frame
# - Word "state/frame of mind". 292 of 543.
# 1 meanings from word "state/frame of mind" and 0 news words to look for.
# - Word "gilt-framed/wood-framed etc". 293 of 543.
# 1 meanings from word "gilt-framed/wood-framed etc" and 0 news words to look for.
# - Word "a fresh start". 294 of 543.
# 1 meanings from word "a fresh start" and 0 news words to look for.
# - Word "fresh air". 295 of 543.
# 1 meanings from word "fresh air" and 1 news words to look for.
# - Word "fresh water". 296 of 544.
# 1 meanings from word "fresh water" and 0 news words to look for.
# - Word "fresh from something". 297 of 544.
# 1 meanings from word "fresh from something" and 0 news words to look for.
# - Word "get/be fresh with somebody". 298 of 544.
# 1 meanings from word "get/be fresh with somebody" and 0 news words to look for.
# - Word "fresh-made/fresh-cut/fresh-grated etc". 299 of 544.
# 1 meanings from word "fresh-made/fresh-cut/fresh-grated etc" and 0 news words to look for.
# - Word "be fresh out of something". 300 of 544.
# 1 meanings from word "be fresh out of something" and 0 news words to look for.
# - Word "reap a harvest". 301 of 544.
# 1 meanings from word "reap a harvest" and 0 news words to look for.
# - Word "be under house arrest". 302 of 544.
# 1 meanings from word "be under house arrest" and 0 news words to look for.
# - Word "hunger for/after". 303 of 544.
# 1 meanings from word "hunger for/after" and 0 news words to look for.
# - Word "in jeopardy". 304 of 544.
# 1 meanings from word "in jeopardy" and 0 news words to look for.
# - Word "cut loose". 305 of 544.
# 1 meanings from word "cut loose" and 0 news words to look for.
# - Word "let somebody loose on something". 306 of 544.
# 1 meanings from word "let somebody loose on something" and 0 news words to look for.
# - Word "be at a loose end". 307 of 544.
# 1 meanings from word "be at a loose end" and 0 news words to look for.
# - Word "loose ends". 308 of 544.
# 1 meanings from word "loose ends" and 0 news words to look for.
# - Word "loose change". 309 of 544.
# 1 meanings from word "loose change" and 0 news words to look for.
# - Word "loose cannon". 310 of 544.
# 1 meanings from word "loose cannon" and 0 news words to look for.
# - Word "hang/stay loose". 311 of 544.
# 1 meanings from word "hang/stay loose" and 0 news words to look for.
# - Word "be on the loose". 312 of 544.
# 1 meanings from word "be on the loose" and 0 news words to look for.
# - Word "the Mob". 313 of 544.
# 2 meanings from word "the Mob" and 0 news words to look for.
# - Word "mob of sheep/cattle". 314 of 544.
# 1 meanings from word "mob of sheep/cattle" and 0 news words to look for.
# - Word "noble gas/metal". 315 of 544.
# 1 meanings from word "noble gas/metal" and 0 news words to look for.
# - Word "noble savage". 316 of 544.
# 1 meanings from word "noble savage" and 0 news words to look for.
# - Word "have a nodding acquaintance (with something)". 317 of 544.
# 1 meanings from word "have a nodding acquaintance (with something)" and 0 news words to look for.
# - Word "have a nodding acquaintance (with somebody)". 318 of 544.
# 1 meanings from word "have a nodding acquaintance (with somebody)" and 0 news words to look for.
# - Word "nod off". 319 of 544.
# 1 meanings from word "nod off" and 0 news words to look for.
# - Word "give somebody the nod/get the nod from somebody". 320 of 544.
# 1 meanings from word "give somebody the nod/get the nod from somebody" and 0 news words to look for.
# - Word "on the nod". 321 of 544.
# 1 meanings from word "on the nod" and 0 news words to look for.
# - Word "land of nod". 322 of 544.
# 1 meanings from word "land of nod" and 0 news words to look for.
# - Word "overturn a decision/verdict etc". 323 of 544.
# 1 meanings from word "overturn a decision/verdict etc" and 0 news words to look for.
# - Word "put/keep somebody in the picture". 324 of 544.
# 1 meanings from word "put/keep somebody in the picture" and 0 news words to look for.
# - Word "get the picture". 325 of 544.
# 1 meanings from word "get the picture" and 0 news words to look for.
# - Word "out of the picture". 326 of 544.
# 1 meanings from word "out of the picture" and 0 news words to look for.
# - Word "be the picture of health/innocence/despair etc". 327 of 544.
# 1 meanings from word "be the picture of health/innocence/despair etc" and 0 news words to look for.
# - Word "be/look a picture". 328 of 544.
# 1 meanings from word "be/look a picture" and 0 news words to look for.
# - Word "pretty as a picture". 329 of 544.
# 1 meanings from word "pretty as a picture" and 0 news words to look for.
# - Word "you could hear a pin drop". 330 of 544.
# 2 meanings from word "you could hear a pin drop" and 0 news words to look for.
# - Word "pins". 331 of 544.
# 1 meanings from word "pins" and 0 news words to look for.
# - Word "drawing pin". 332 of 544.
# 1 meanings from word "drawing pin" and 0 news words to look for.
# 5 images were imported from word drawing pin
# - Word "pin money". 333 of 544.
# 1 meanings from word "pin money" and 0 news words to look for.
# 5 images were imported from word pin money
# - Word "pins and needles". 334 of 544.
# 1 meanings from word "pins and needles" and 0 news words to look for.
# 5 images were imported from word pins and needles
# - Word "rolling pin". 335 of 544.
# 1 meanings from word "rolling pin" and 0 news words to look for.
# 5 images were imported from word rolling pin
# - Word "safety pin". 336 of 544.
# 1 meanings from word "safety pin" and 0 news words to look for.
# 5 images were imported from word safety pin
# - Word "pool of water/blood/light etc". 337 of 544.
# 1 meanings from word "pool of water/blood/light etc" and 0 news words to look for.
# - Word "the pools". 338 of 544.
# 1 meanings from word "the pools" and 0 news words to look for.
# - Word "coffee pot". 339 of 544.
# 1 meanings from word "coffee pot" and 0 news words to look for.
# 5 images were imported from word coffee pot
# - Word "go to pot". 340 of 544.
# 1 meanings from word "go to pot" and 0 news words to look for.
# - Word "pots of money". 341 of 544.
# 1 meanings from word "pots of money" and 0 news words to look for.
# - Word "the pot". 342 of 544.
# 1 meanings from word "the pot" and 0 news words to look for.
# - Word "(a case of) the pot calling the kettle black". 343 of 544.
# 1 meanings from word "(a case of) the pot calling the kettle black" and 0 news words to look for.
# - Word "chamber pot". 344 of 544.
# 1 meanings from word "chamber pot" and 0 news words to look for.
# 5 images were imported from word chamber pot
# - Word "chimney pot". 345 of 544.
# 1 meanings from word "chimney pot" and 0 news words to look for.
# 5 images were imported from word chimney pot
# - Word "flowerpot". 346 of 544.
# 1 meanings from word "flowerpot" and 0 news words to look for.
# 5 images were imported from word flowerpot
# - Word "lobsterpot". 347 of 544.
# 1 meanings from word "lobsterpot" and 0 news words to look for.
# 5 images were imported from word lobsterpot
# - Word "melting pot". 348 of 544.
# 2 meanings from word "melting pot" and 0 news words to look for.
# 5 images were imported from word melting pot
# - Word "this/that puppy". 349 of 544.
# 1 meanings from word "this/that puppy" and 0 news words to look for.
# - Word "be remembered for/as something". 350 of 544.
# 1 meanings from word "be remembered for/as something" and 0 news words to look for.
# - Word "remember me to somebody". 351 of 544.
# 1 meanings from word "remember me to somebody" and 0 news words to look for.
# - Word "let me remind you/may I remind you (that)". 352 of 544.
# 1 meanings from word "let me remind you/may I remind you (that)" and 0 news words to look for.
# - Word "a roof over your head". 353 of 544.
# 1 meanings from word "a roof over your head" and 0 news words to look for.
# - Word "go through the roof". 354 of 544.
# 1 meanings from word "go through the roof" and 0 news words to look for.
# - Word "under the same roof/under one roof". 355 of 544.
# 1 meanings from word "under the same roof/under one roof" and 0 news words to look for.
# - Word "the roof falls/caves in". 356 of 544.
# 1 meanings from word "the roof falls/caves in" and 0 news words to look for.
# - Word "raise the roof". 357 of 544.
# 1 meanings from word "raise the roof" and 0 news words to look for.
# - Word "sunroof". 358 of 544.
# 1 meanings from word "sunroof" and 0 news words to look for.
# 5 images were imported from word sunroof
# - Word "not a sausage!". 359 of 544.
# 1 meanings from word "not a sausage!" and 0 news words to look for.
# - Word "seeds of something". 360 of 544.
# 1 meanings from word "seeds of something" and 0 news words to look for.
# - Word "go/run to seed". 361 of 544.
# 1 meanings from word "go/run to seed" and 0 news words to look for.
# - Word "number one/two/three etc seed". 362 of 544.
# 1 meanings from word "number one/two/three etc seed" and 0 news words to look for.
# - Word "seed itself". 363 of 544.
# 1 meanings from word "seed itself" and 0 news words to look for.
# - Word "shake your head". 364 of 544.
# 1 meanings from word "shake your head" and 0 news words to look for.
# - Word "shake your fist (at somebody)". 365 of 544.
# 1 meanings from word "shake your fist (at somebody)" and 0 news words to look for.
# - Word "shake a leg". 366 of 544.
# 1 meanings from word "shake a leg" and 0 news words to look for.
# - Word "shake down". 367 of 544.
# 3 meanings from word "shake down" and 0 news words to look for.
# - Word "shake out". 368 of 544.
# 3 meanings from word "shake out" and 0 news words to look for.
# - Word "the shakes". 369 of 544.
# 1 meanings from word "the shakes" and 0 news words to look for.
# - Word "in a couple of shakes/two shakes". 370 of 544.
# 1 meanings from word "in a couple of shakes/two shakes" and 0 news words to look for.
# - Word "no great shakes". 371 of 544.
# 1 meanings from word "no great shakes" and 0 news words to look for.
# - Word "get/give somebody a fair shake". 372 of 544.
# 1 meanings from word "get/give somebody a fair shake" and 0 news words to look for.
# - Word "shrink from". 373 of 544.
# 1 meanings from word "shrink from" and 0 news words to look for.
# - Word "not a pretty sight". 374 of 544.
# 1 meanings from word "not a pretty sight" and 0 news words to look for.
# - Word "in/within sight". 375 of 544.
# 1 meanings from word "in/within sight" and 0 news words to look for.
# - Word "within/in sight of something". 376 of 544.
# 1 meanings from word "within/in sight of something" and 0 news words to look for.
# - Word "in your sights". 377 of 544.
# 1 meanings from word "in your sights" and 0 news words to look for.
# - Word "out of sight". 378 of 544.
# 1 meanings from word "out of sight" and 0 news words to look for.
# - Word "out of sight, out of mind". 379 of 544.
# 1 meanings from word "out of sight, out of mind" and 0 news words to look for.
# - Word "disappear/vanish from sight". 380 of 544.
# 1 meanings from word "disappear/vanish from sight" and 0 news words to look for.
# - Word "come into sight". 381 of 544.
# 1 meanings from word "come into sight" and 0 news words to look for.
# - Word "on sight". 382 of 544.
# 1 meanings from word "on sight" and 0 news words to look for.
# - Word "not let somebody out of your sight". 383 of 544.
# 1 meanings from word "not let somebody out of your sight" and 0 news words to look for.
# - Word "a sight for sore eyes". 384 of 544.
# 1 meanings from word "a sight for sore eyes" and 0 news words to look for.
# - Word "a (damn/darned/darn) sight more/better etc". 385 of 544.
# 1 meanings from word "a (damn/darned/darn) sight more/better etc" and 0 news words to look for.
# - Word "be a sight". 386 of 544.
# 1 meanings from word "be a sight" and 0 news words to look for.
# - Word "sight unseen". 387 of 544.
# 1 meanings from word "sight unseen" and 0 news words to look for.
# - Word "be a (beautiful/strange/frightening etc) sight to behold". 388 of 544.
# 1 meanings from word "be a (beautiful/strange/frightening etc) sight to behold" and 0 news words to look for.
# - Word "at first glance/sight". 389 of 544.
# 2 meanings from word "at first glance/sight" and 0 news words to look for.
# - Word "set your heart/mind/sights on (doing) something". 390 of 544.
# 1 meanings from word "set your heart/mind/sights on (doing) something" and 0 news words to look for.
# - Word "slum it/be slumming". 391 of 544.
# 1 meanings from word "slum it/be slumming" and 0 news words to look for.
# - Word "be born with a silver spoon in your mouth". 392 of 544.
# 1 meanings from word "be born with a silver spoon in your mouth" and 0 news words to look for.
# - Word "dessertspoon". 393 of 544.
# 2 meanings from word "dessertspoon" and 0 news words to look for.
# 5 images were imported from word dessertspoon
# - Word "greasy spoon". 394 of 544.
# 1 meanings from word "greasy spoon" and 0 news words to look for.
# 5 images were imported from word greasy spoon
# - Word "soup spoon". 395 of 544.
# ...
# - Word "strike up". 425 of 544.
# 2 meanings from word "strike up" and 0 news words to look for.
# - Word "first strike". 426 of 544.
# 1 meanings from word "first strike" and 0 news words to look for.
# 5 images were imported from word first strike
# - Word "two/three strikes against somebody/something". 427 of 544.
# 1 meanings from word "two/three strikes against somebody/something" and 0 news words to look for.
# - Word "hunger strike". 428 of 544.
# 1 meanings from word "hunger strike" and 0 news words to look for.
# 5 images were imported from word hunger strike
# - Word "lightning strike". 429 of 544.
# 1 meanings from word "lightning strike" and 0 news words to look for.
# 5 images were imported from word lightning strike
# - Word "stubborn resistance/refusal/determination etc". 430 of 544.
# 1 meanings from word "stubborn resistance/refusal/determination etc" and 0 news words to look for.
# - Word "the terraces". 431 of 544.
# 1 meanings from word "the terraces" and 0 news words to look for.
# - Word "be at the end of your tether". 432 of 544.
# 1 meanings from word "be at the end of your tether" and 0 news words to look for.
# - Word "paper towel". 433 of 544.
# 1 meanings from word "paper towel" and 0 news words to look for.
# 5 images were imported from word paper towel
# - Word "tea towel". 434 of 544.
# 1 meanings from word "tea towel" and 0 news words to look for.
# 5 images were imported from word tea towel
# - Word "throw in the towel". 435 of 544.
# 0 meanings from word "throw in the towel" and 0 news words to look for.
# - Word "towelling". 436 of 544.
# 1 meanings from word "towelling" and 0 news words to look for.
# 5 images were imported from word towelling
# - Word "the vertical". 437 of 544.
# 1 meanings from word "the vertical" and 0 news words to look for.
# - Word "wipe something from your mind/memory". 438 of 544.
# 1 meanings from word "wipe something from your mind/memory" and 0 news words to look for.
# - Word "wipe the floor with somebody". 439 of 544.
# 1 meanings from word "wipe the floor with somebody" and 0 news words to look for.
# - Word "wipe the slate clean". 440 of 544.
# 1 meanings from word "wipe the slate clean" and 0 news words to look for.
# - Word "wipe something off the face of the earth/wipe something off the map". 441 of 544.
# 1 meanings from word "wipe something off the face of the earth/wipe something off the map" and 0 news words to look for.
# - Word "wipe out". 442 of 544.
# 3 meanings from word "wipe out" and 0 news words to look for.
# - Word "the cutting edge (of something)". 443 of 544.
# 1 meanings from word "the cutting edge (of something)" and 0 news words to look for.
# - Word "a breath of fresh air". 444 of 544.
# 1 meanings from word "a breath of fresh air" and 0 news words to look for.
# - Word "be on pins and needles". 445 of 544.
# 1 meanings from word "be on pins and needles" and 0 news words to look for.
# - Word "in the melting pot". 446 of 544.
# 1 meanings from word "in the melting pot" and 0 news words to look for.
# - Word "win/collect/take etc the wooden spoon". 447 of 544.
# 1 meanings from word "win/collect/take etc the wooden spoon" and 0 news words to look for.
# - Word "the Gulf Stream". 448 of 544.
# 1 meanings from word "the Gulf Stream" and 0 news words to look for.
# - Word "the mainstream". 449 of 544.
# 1 meanings from word "the mainstream" and 0 news words to look for.
# - Word "ballistic missile". 450 of 544.
# 1 meanings from word "ballistic missile" and 0 news words to look for.
# 5 images were imported from word ballistic missile
# - Word "cruise missile". 451 of 544.
# 1 meanings from word "cruise missile" and 0 news words to look for.
# 5 images were imported from word cruise missile
# - Word "guided missile". 452 of 544.
# 1 meanings from word "guided missile" and 0 news words to look for.
# 5 images were imported from word guided missile
# - Word "biological clock". 453 of 544.
# 2 meanings from word "biological clock" and 0 news words to look for.
# 5 images were imported from word biological clock
# - Word "body clock". 454 of 544.
# 1 meanings from word "body clock" and 0 news words to look for.
# 5 images were imported from word body clock
# - Word "dandelion clock". 455 of 544.
# 1 meanings from word "dandelion clock" and 0 news words to look for.
# 5 images were imported from word dandelion clock
# - Word "time clock". 456 of 544.
# 1 meanings from word "time clock" and 0 news words to look for.
# 5 images were imported from word time clock
# - Word "watch the clock". 457 of 544.
# 1 meanings from word "watch the clock" and 0 news words to look for.
# - Word "around the clock". 458 of 544.
# 2 meanings from word "around the clock" and 0 news words to look for.
# - Word "put/turn the clock back". 459 of 544.
# 1 meanings from word "put/turn the clock back" and 0 news words to look for.
# - Word "put the clock(s) back/forward". 460 of 544.
# 1 meanings from word "put the clock(s) back/forward" and 0 news words to look for.
# - Word "the clocks go back/forward". 461 of 544.
# 1 meanings from word "the clocks go back/forward" and 0 news words to look for.
# - Word "against the clock". 462 of 544.
# 1 meanings from word "against the clock" and 0 news words to look for.
# - Word "twenty-four hour clock". 463 of 544.
# 1 meanings from word "twenty-four hour clock" and 0 news words to look for.
# - Word "start/stop the clock". 464 of 544.
# 1 meanings from word "start/stop the clock" and 0 news words to look for.
# - Word "the clock is ticking". 465 of 544.
# 1 meanings from word "the clock is ticking" and 0 news words to look for.
# - Word "the clock". 466 of 544.
# 1 meanings from word "the clock" and 0 news words to look for.
# - Word "run out the clock/kill the clock". 467 of 544.
# 1 meanings from word "run out the clock/kill the clock" and 0 news words to look for.
# - Word "clock in/on". 468 of 544.
# 1 meanings from word "clock in/on" and 0 news words to look for.
# - Word "clock off". 469 of 544.
# 2 meanings from word "clock off" and 0 news words to look for.
# - Word "clock out". 470 of 544.
# 1 meanings from word "clock out" and 0 news words to look for.
# - Word "clock up". 471 of 544.
# 1 meanings from word "clock up" and 0 news words to look for.
# - Word "watch somebody like a hawk". 472 of 544.
# 1 meanings from word "watch somebody like a hawk" and 0 news words to look for.
# - Word "watch (out) for". 473 of 544.
# 1 meanings from word "watch (out) for" and 0 news words to look for.
# - Word "watch out". 474 of 544.
# 1 meanings from word "watch out" and 0 news words to look for.
# - Word "watch over". 475 of 544.
# 1 meanings from word "watch over" and 0 news words to look for.
# - Word "watch your step". 476 of 544.
# 2 meanings from word "watch your step" and 0 news words to look for.
# - Word "watch your back". 477 of 544.
# 1 meanings from word "watch your back" and 0 news words to look for.
# - Word "watch the time". 478 of 544.
# 1 meanings from word "watch the time" and 0 news words to look for.
# - Word "watch it". 479 of 544.
# 1 meanings from word "watch it" and 0 news words to look for.
# - Word "watch this space". 480 of 544.
# 1 meanings from word "watch this space" and 0 news words to look for.
# - Word "one to watch". 481 of 544.
# 1 meanings from word "one to watch" and 0 news words to look for.
# - Word "watch the world go by". 482 of 544.
# 1 meanings from word "watch the world go by" and 0 news words to look for.
# - Word "you watch". 483 of 544.
# 1 meanings from word "you watch" and 0 news words to look for.
# - Word "keep a watch out for somebody/something". 484 of 544.
# 1 meanings from word "keep a watch out for somebody/something" and 0 news words to look for.
# - Word "neighbourhood watch". 485 of 544.
# 1 meanings from word "neighbourhood watch" and 0 news words to look for.
# 5 images were imported from word neighbourhood watch
# - Word "nail in somebody’s/something’s coffin". 486 of 544.
# 1 meanings from word "nail in somebody’s/something’s coffin" and 0 news words to look for.
# - Word "make somebody’s toes curl". 487 of 544.
# 1 meanings from word "make somebody’s toes curl" and 0 news words to look for.
# - Word "curl of somebody’s lip/mouth". 488 of 544.
# 1 meanings from word "curl of somebody’s lip/mouth" and 0 news words to look for.
# - Word "tickle somebody’s fancy". 489 of 544.
# 2 meanings from word "tickle somebody’s fancy" and 0 news words to look for.
# - Word "like it’s going out of fashion". 490 of 544.
# 1 meanings from word "like it’s going out of fashion" and 0 news words to look for.
# - Word "cat flap". 491 of 544.
# 1 meanings from word "cat flap" and 0 news words to look for.
# 5 images were imported from word cat flap
# - Word "a flap". 492 of 544.
# 1 meanings from word "a flap" and 0 news words to look for.
# - Word "not mince (your) words". 493 of 544.
# 1 meanings from word "not mince (your) words" and 0 news words to look for.
# - Word "a nod’s as good as a wink". 494 of 544.
# 1 meanings from word "a nod’s as good as a wink" and 0 news words to look for.
# - Word "for two pins I’d ...". 495 of 544.
# 1 meanings from word "for two pins I’d ..." and 0 news words to look for.
# - Word "without prejudice (to something)". 496 of 544.
# 1 meanings from word "without prejudice (to something)" and 0 news words to look for.
# - Word "to the prejudice of something". 497 of 544.
# 1 meanings from word "to the prejudice of something" and 0 news words to look for.
# - Word "don’t remind me". 498 of 544.
# 1 meanings from word "don’t remind me" and 0 news words to look for.
# - Word "the roof of somebody’s mouth". 499 of 544.
# 1 meanings from word "the roof of somebody’s mouth" and 0 news words to look for.
# - Word "under somebody’s roof". 500 of 544.
# 1 meanings from word "under somebody’s roof" and 0 news words to look for.
# - Word "shake somebody’s hand/shake hands with somebody". 501 of 544.
# 1 meanings from word "shake somebody’s hand/shake hands with somebody" and 0 news words to look for.
# - Word "shake somebody’s confidence/beliefs etc". 502 of 544.
# 1 meanings from word "shake somebody’s confidence/beliefs etc" and 0 news words to look for.
# - Word "somebody’s voice shakes". 503 of 544.
# 1 meanings from word "somebody’s voice shakes" and 0 news words to look for.
# - Word "be sick of/can’t stand/hate the sight of somebody/something". 504 of 544.
# 1 meanings from word "be sick of/can’t stand/hate the sight of somebody/something" and 0 news words to look for.
# - Word "sow your wild oats". 505 of 544.
# 1 meanings from word "sow your wild oats" and 0 news words to look for.
# - Word "sponsored walk/swim etc". 506 of 544.
# 1 meanings from word "sponsored walk/swim etc" and 0 news words to look for.
# - Word "UN-sponsored/US-sponsored/government-sponsored etc". 507 of 544.
# 1 meanings from word "UN-sponsored/US-sponsored/government-sponsored etc" and 0 news words to look for.
# - Word "strike terror/fear into somebody’s heart". 508 of 544.
# 1 meanings from word "strike terror/fear into somebody’s heart" and 0 news words to look for.
# - Word "the fast lane". 509 of 544.
# 1 meanings from word "the fast lane" and 0 news words to look for.
# - Word "a walk/trip down memory lane". 510 of 544.
# 1 meanings from word "a walk/trip down memory lane" and 0 news words to look for.
# - Word "drive a wedge between somebody". 511 of 544.
# 1 meanings from word "drive a wedge between somebody" and 0 news words to look for.
# - Word "wedges". 512 of 544.
# 1 meanings from word "wedges" and 0 news words to look for.
# - Word "wedge something open/shut". 513 of 544.
# 1 meanings from word "wedge something open/shut" and 0 news words to look for.
# - Word "like weeds". 514 of 544.
# 1 meanings from word "like weeds" and 0 news words to look for.
# - Word "the weed". 515 of 544.
# 1 meanings from word "the weed" and 0 news words to look for.
# - Word "(widow’s) weeds". 516 of 544.
# 1 meanings from word "(widow’s) weeds" and 0 news words to look for.
# - Word "wipe the smile/grin off somebody’s face". 517 of 544.
# 1 meanings from word "wipe the smile/grin off somebody’s face" and 0 news words to look for.
# - Word "the deaf". 518 of 544.
# 1 meanings from word "the deaf" and 0 news words to look for.
# - Word "in a ... fashion". 519 of 544.
# 1 meanings from word "in a ... fashion" and 0 news words to look for.
# - Word "frame of mind". 520 of 544.
# 0 meanings from word "frame of mind" and 0 news words to look for.
# - Word "let (something ?) loose". 521 of 544.
# 1 meanings from word "let (something ?) loose" and 0 news words to look for.
# - Word "the land of nod". 522 of 544.
# 0 meanings from word "the land of nod" and 0 news words to look for.
# - Word "know somebody by sight". 523 of 544.
# 0 meanings from word "know somebody by sight" and 0 news words to look for.
# - Word "lose sight of something". 524 of 544.
# 0 meanings from word "lose sight of something" and 0 news words to look for.
# - Word "Gulf Stream". 525 of 544.
# 0 meanings from word "Gulf Stream" and 0 news words to look for.
# - Word "ego trip". 526 of 544.
# 1 meanings from word "ego trip" and 0 news words to look for.
# 5 images were imported from word ego trip
# - Word "guilt trip". 527 of 544.
# 1 meanings from word "guilt trip" and 0 news words to look for.
# - Word "round-trip". 528 of 544.
# 2 meanings from word "round-trip" and 0 news words to look for.
# 5 images were imported from word round-trip
# - Word "trip up". 529 of 544.
# 2 meanings from word "trip up" and 0 news words to look for.
# - Word "trip off the tongue". 530 of 544.
# 1 meanings from word "trip off the tongue" and 0 news words to look for.
# - Word "trip the light fantastic". 531 of 544.
# Bad gateway. {
# Error on ChatGPT module: Bad gateway. {"error":{"code":502,"message":"Bad gateway.","param":null,"type":"cf_bad_gateway"}} 502 {'error': {'code': 502, 'message': 'Bad gateway.', 'param': None, 'type': 'cf_bad_gateway'}} {'Date': 'Sun, 02 Jul 2023 03:50:44 GMT', 'Content-Type': 'application/json', 'Content-Length': '84', 'Connection': 'keep-alive', 'X-Frame-Options': 'SAMEORIGIN', 'Referrer-Policy': 'same-origin', 'Cache-Control': 'private, max-age=0, no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Expires': 'Thu, 01 Jan 1970 00:00:01 GMT', 'Server': 'cloudflare', 'CF-RAY': '7e03e58a8afb4ecb-GRU', 'alt-svc': 'h3=":443"; ma=86400'}
# ChatGPT could not to return the translation by a error process.
# 1 meanings from word "trip the light fantastic" and 0 news words to look for.
# - Word "X-rated". 532 of 544.
# 1 meanings from word "X-rated" and 0 news words to look for.
# - Word "X number of people/things". 533 of 544.
# 1 meanings from word "X number of people/things" and 0 news words to look for.
# - Word "X marks the spot". 534 of 544.
# 1 meanings from word "X marks the spot" and 0 news words to look for.
# - Word "X". 535 of 544.
# 9 meanings from word "X" and 0 news words to look for.
# 5 images were imported from word X
# - Word "a nail in somebody’s/something’s coffin". 536 of 544.
# 1 meanings from word "a nail in somebody’s/something’s coffin" and 0 news words to look for.
# - Word "make your hair curl". 537 of 544.
# 1 meanings from word "make your hair curl" and 0 news words to look for.
# - Word "flight of fancy". 538 of 544.
# 1 meanings from word "flight of fancy" and 0 news words to look for.
# - Word "let (something ↔) loose". 539 of 544.
# 1 meanings from word "let (something ↔) loose" and 0 news words to look for.
# - Word "at first sight". 540 of 544.
# 2 meanings from word "at first sight" and 1 news words to look for.
# - Word "blow your top/stack". 541 of 545.
# 1 meanings from word "blow your top/stack" and 0 news words to look for.
# - Word "life in the fast lane". 542 of 545.
# 1 meanings from word "life in the fast lane" and 0 news words to look for.
# - Word "walk/trip down memory lane". 543 of 545.
# 1 meanings from word "walk/trip down memory lane" and 0 news words to look for.
# - Word "breath of fresh air". 544 of 545.
# 1 meanings from word "breath of fresh air" and 0 news words to look for.
# - Word "love at first sight". 545 of 545.
# 9 meanings from word "love at first sight" and 0 news words to look for.
# 5 images were imported from word love at first sight
#
# Chat GPT spends: 78849 tokens and 0.1576979999999999 dolars.
# 1055 meanings from 545 words were found and mapped.
#
# Searching meanings is finished.

# %%
print('\n\n###################################################################')
# Out:
# ###################################################################

# %% [markdown]
# ### Export results

# %%
file_datetime = time.strftime("%Y%m%d_%H%M%S", time.localtime(int(time.time())))

# Export meanings
if not os.path.exists("words_" + file_datetime + ".csv"):    
    export_to_csv([columns_names] + list_ex, "words_" + file_datetime + ".csv")
    print('The file ' + "words_" + file_datetime + ".csv" + ' was created with the meanings from the inputed words.')
else:
    i = 1
    while os.path.exists("words_" + file_datetime + "_" + str(i).zfill(2) + ".csv"):
        i += 1
    export_to_csv([columns_names] + list_ex, "words_" + file_datetime + "_" + str(i).zfill(2) + ".csv")
    print('The log file ' + "words_" + "words_" + file_datetime + "_" + str(i).zfill(2) + ".csv" + ' was created from the inputed words.')

# Export log
if not os.path.exists("words_" + file_datetime + ".csv"):    
    export_to_csv([log_columns_names] + log, "log_" + file_datetime + ".csv")
    print('The file ' + "log_" + file_datetime + ".csv" + ' was created with the meanings from the inputed words.')
else:
    i = 1
    while os.path.exists("words_" + file_datetime + "_" + str(i).zfill(2) + ".csv"):
        i += 1
    export_to_csv([log_columns_names] + log, "log_" + file_datetime + ".csv")
    print('The log file ' + "words_" + "log_" + file_datetime + "_" + str(i).zfill(2) + ".csv" + ' was created from the inputed words.')
          
time.sleep(10)
# Out:
# The file words_20230702_005323.csv was created with the meanings from the inputed words.
# The log file words_log_20230702_005323_01.csv was created from the inputed words.
